# %%
import pandas as pd
import pyreadstat as pyr

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df, meta = pyr.read_sav('afrobarometer.sav')

# %%
def wrangle(filename):
    # Load file as DataFrame
    df, meta = pyr.read_sav(filename)
    # Select columns 
    df = df[['RESPNO','COUNTRY', 'URBRUR', 'REGION', 'Q3', 'Q4A', 'Q6', 'Q40', 'Q43G', 'Q49T']]
    # Replaces the code numbers with the actual values in each column
    list = ['COUNTRY', 'URBRUR', 'REGION', 'Q3', 'Q4A', 'Q6', 'Q40', 'Q43G', 'Q49T']
    for i in list:
        x = meta.variable_value_labels[i]
        df[i].replace(x, inplace=True)
    # Renames columns    
    df.columns = ['id', 'country', 'community', 'state', 'ctry_direction', 'ctry_present_econ',
              'rel_econ_past12m', 'fear_pol_intimidation', 'trust_police', 'pay_bribe_police']

    # Changes index to id
    df.set_index('id', inplace=True)
    
    return df

# %%
df = wrangle('afrobarometer.sav')

# %%
columns = ['COUNTRY','REGION','Q10A','Q10B','Q11A','Q11B','Q43G', 'Q44E', 'Q49P','Q49Q','Q49R','Q49T']
df_police = df.copy()[columns]
for i in columns:
    x = meta.variable_value_labels[i]
    df_police[i].replace(x, inplace=True)

# %%
df_police.head()
# Out:
#   country       state neigborhood_safety fear_of_crime stolen_from attacked  \
# 0   Benin        Mono      Several times         Never          No       No
# 1   Benin        Mono              Never         Never          No       No
# 2   Benin  Atlantique              Never         Never          No       No
# 3   Benin  Atlantique      Several times         Never          No       No
# 4   Benin  Atlantique              Never         Never          No       No
#
#     trust_police corrupt_police ease_of_police_assist time_to_police_assist  \
# 0          A lot   Some of them            No contact            No contact
# 1       Somewhat   Some of them            No contact            No contact
# 2  Just a little   Most of them                  Easy            Right away
# 3          A lot   Some of them            No contact            No contact
# 4  Just a little   Most of them            No contact            No contact
#
#   paybribe_police_assist paybribe_avoid_police
# 0             No contact            No contact
# 1             No contact            No contact
# 2                  Never            No contact
# 3             No contact            No contact
# 4             No contact            No contact

# %%
df_police.columns = ['country', 'state', 'neigborhood_safety', 'fear_of_crime',
              'stolen_from', 'attacked', 'trust_police', 'corrupt_police',
               'ease_of_police_assist','time_to_police_assist', 'paybribe_police_assist', 'paybribe_avoid_police']

# %%
print(meta.column_names_to_labels)
meta.variable_value_labels
# Out:
# {'RESPNO': 'Respondent number', 'COUNTRY': 'Country', 'COUNTRY_Old.order': 'Country in R7 Old Alphabetical Order', 'COUNTRY_R5List': 'Country in R5 Alphabetical Order', 'COUNTRY_R6List': 'Country in R6 Alphabetical Order', 'COUNTRY.BY.REGION': 'Country by Region', 'URBRUR': 'Urban or Rural Primary Sampling Unit', 'REGION': 'Province or region', 'LOCATION.LEVEL.1': 'Location Level 1', 'EA_SVC_A': 'EA-SVC-A. Electricity grid in the PSU/EA', 'EA_SVC_B': 'EA-SVC-B. Piped water system in the PSU/EA', 'EA_SVC_C': 'EA-SVC-C. Sewage system in the PSU/EA', 'EA_SVC_D': 'EA-SVC-D. Cell phone service in the PSU/EA', 'EA_FAC_A': 'EA-FAC-A. Post office in the PSU/EA', 'EA_FAC_B': 'EA-FAC-B. School in the PSU/EA', 'EA_FAC_C': 'EA-FAC-C. Police station in the PSU/EA', 'EA_FAC_D': 'EA-FAC-D. Health Clinic in the PSU/EA', 'EA_FAC_E': 'EA-FAC-E. Market stalls in the PSU/EA', 'EA_FAC_F': 'EA-FAC-F. Bank in the PSU/EA', 'EA_FAC_G': 'EA-FAC-G. Paid transport in the PSU/EA', 'EA_SEC_A': 'EA-SEC-A. Police in the PSU/EA', 'EA_SEC_B': 'EA-SEC-B. Soldiers/army in the PSU/EA', 'EA_SEC_C': 'EA-SEC-C. Roadblocks by police/army in the PSU/EA', 'EA_SEC_D': 'EA-SEC-D. Customs checkpoints in the PSU/EA', 'EA_SEC_E': 'EA-SEC-E. Roadblocks by private security/local community in the PSU/EA', 'EA_ROAD_A': 'EA-ROAD-A. Road surface at start point', 'EA_ROAD_B': 'EA-ROAD-B. Road surface last 5 km', 'EA_ROAD_C': 'EA-ROAD-C. Road condition last 5 km', 'NOCALL_1': 'Reason for Unsuccessful Call Household 1', 'NOCALL_1OTHER': 'Reason for Unsuccessful Call Household 1 (Verbatim)', 'NOCALL_2': 'Reason for Unsuccessful Call Household 2', 'NOCALL_2OTHER': 'Reason for Unsuccessful Call Household 2 (Verbatim)', 'NOCALL_3': 'Reason for Unsuccessful Call Household 3', 'NOCALL_3OTHER': 'Reason for Unsuccessful Call Household 3 (Verbatim)', 'NOCALL_4': 'Reason for Unsuccessful Call Household 4', 'NOCALL_4OTHER': 'Reason for Unsuccessful Call Household 4 (Verbatim)', 'NOCALL_5': 'Reason for Unsuccessful Call Household 5', 'NOCALL_6': 'Reason for Unsuccessful Call Household 6', 'NOCALL_7': 'Reason for Unsuccessful Call Household 7', 'NOCALL_7OTHER': 'Reason for Unsuccessful Call Household 7 (Verbatim)', 'NOCALL_8': 'Reason for Unsuccessful Call Household 8', 'THISINT': 'This interview, gender', 'ADULT_CT': 'Number of adults in household', 'CALLS': 'Number of calls', 'DATEINTR': 'Date of interview', 'STRTIME': 'Time interview started', 'Q1': 'Q1. Age', 'Q2A': "Q2a. Respondent's mother tongue", 'Q2AOTHER': "Q2aother. Respondent's mother tongue (verbatim)", 'Q2B': 'Q2b. Language spoken in home', 'Q2BOTHER': 'Q2bother. Language spoken in home (verbatim)', 'Q3': 'Q3. Overall direction of the country', 'Q4A': 'Q4a. Country’s present economic condition', 'Q4B': 'Q4b. Your present living conditions', 'Q5': 'Q5. Your living conditions vs. others', 'Q6': 'Q6. Country’s economic condition compared to 12 months ago', 'Q7': 'Q7. Country’s economic condition in 12 months’ time', 'Q8A': 'Q8a. How often gone without food', 'Q8B': 'Q8b. How often gone without water', 'Q8C': 'Q8c. How often gone without medical care', 'Q8D': 'Q8d. How often gone without cooking fuel', 'Q8E': 'Q8e. How often gone without cash income', 'Q8F': 'Q8f. Frequency going without basic necessities', 'Q9': 'Q9. How dependent on receiving remittances', 'Q10A': 'Q10a. How often felt unsafe walking in neighbourhood', 'Q10B': 'Q10b. How often feared crime in home', 'Q11A': 'Q11a. Had something stolen from house', 'Q11B': 'Q11b. Have been physically attacked', 'Q12A': 'Q12a. Radio news', 'Q12B': 'Q12b. Television news', 'Q12C': 'Q12c. Newspaper news', 'Q12D': 'Q12d. Internet news', 'Q12E': 'Q12e. Social media news', 'Q13': 'Q13. Discuss politics', 'Q14': 'Q14. Freedom to say what you think', 'Q15': 'Q15. Government bans organizations vs. join any', 'Q16': 'Q16. Men only as leaders vs. women leaders', 'Q17': 'Q17. Media free to publish vs. government control', 'Q18A': 'Q18a. Access to information: school budget', 'Q18B': 'Q18b. Access ...
# {'COUNTRY': {1.0: 'Benin',
#   2.0: 'Botswana',
#   3.0: 'Burkina Faso',
#   4.0: 'Cabo Verde',
#   5.0: 'Cameroon',
#   6.0: "Côte d'Ivoire",
#   7.0: 'eSwatini',
#   8.0: 'Gabon',
#   9.0: 'Gambia',
#   10.0: 'Ghana',
#   11.0: 'Guinea',
#   12.0: 'Kenya',
#   13.0: 'Lesotho',
#   14.0: 'Liberia',
#   15.0: 'Madagascar',
#   16.0: 'Malawi',
#   17.0: 'Mali',
#   18.0: 'Mauritius',
#   19.0: 'Morocco',
#   20.0: 'Mozambique',
#   21.0: 'Namibia',
#   22.0: 'Niger',
#   23.0: 'Nigeria',
#   24.0: 'São Tomé and Príncipe',
#   25.0: 'Senegal',
#   26.0: 'Sierra Leone',
#   27.0: 'South Africa',
#   28.0: 'Sudan',
#   29.0: 'Tanzania',
#   30.0: 'Togo',
#   31.0: 'Tunisia',
#   32.0: 'Uganda',
#   33.0: 'Zambia',
#   34.0: 'Zimbabwe'},
#  'COUNTRY_Old.order': {1.0: 'Benin',
#   2.0: 'Botswana',
#   3.0: 'Burkina Faso',
#   4.0: 'Cameroon',
#   5.0: 'Cabo Verde',
#   6.0: "Côte d'Ivoire",
#   7.0: 'Gabon',
#   8.0: 'Gambia',
#   9.0: 'Ghana',
#   10.0: 'Guinea',
#   11.0: 'Kenya',
#   12.0: 'Lesotho',
#   13.0: 'Liberia',
#   14.0: 'Madagascar',
#   15.0: 'Malawi',
#   16.0: 'Mali',
#   17.0: 'Mauritius',
#   18.0: 'Morocco',
#   19.0: 'Mozambique',
#   20.0: 'Namibia',
#   21.0: 'Niger',
#   22.0: 'Nigeria',
#   23.0: 'São Tomé and Príncipe',
#   24.0: 'Senegal',
#   25.0: 'Sierra Leone',
#   26.0: 'South Africa',
#   27.0: 'Sudan',
#   28.0: 'Swaziland',
#   29.0: 'Tanzania',
#   30.0: 'Togo',
#   31.0: 'Tunisia',
#   32.0: 'Uganda',
#   33.0: 'Zambia',
#   34.0: 'Zimbabwe'},
#  'COUNTRY_R5List': {1.0: 'Algeria',
#   2.0: 'Benin',
#   3.0: 'Botswana',
#   4.0: 'Burkina Faso',
#   5.0: 'Burundi',
#   6.0: 'Cameroon',
#   7.0: 'Cabo Verde',
#   8.0: "Côte d'Ivoire",
#   9.0: 'Egypt',
#   11.0: 'Ghana',
#   12.0: 'Guinea',
#   13.0: 'Kenya',
#   14.0: 'Lesotho',
#   15.0: 'Liberia',
#   16.0: 'Madagascar',
#   17.0: 'Malawi',
#   18.0: 'Mali',
#   19.0: 'Mauritius',
#   20.0: 'Morocco',
#   21.0: 'Mozambique',
#   22.0: 'Namibia',
#   23.0: 'Niger',
#   24.0: 'Nigeria',
#   25.0: 'Senegal',
#   26.0: 'Sierra Leone',
#   27.0: 'South Africa',
#   28.0: 'Sudan',
#   29.0: 'Swaziland',
#   30.0: 'Tanzania',
#   31.0: 'Togo',
#   32.0: 'Tunisia',
#   33.0: 'Uganda',
#   34.0: 'Zambia',
#   35.0: 'Zimbabwe',
#   36.0: 'Gabon',
#   37.0: 'Gambia',
#   38.0: 'São Tomé and Príncipe'},
#  'COUNTRY_R6List': {1.0: 'Algeria',
#   2.0: 'Benin',
#   3.0: 'Botswana',
#   4.0: 'Burkina Faso',
#   5.0: 'Burundi',
#   6.0: 'Cameroon',
#   7.0: 'Cabo Verde',
#   8.0: "Côte d'Ivoire",
#   9.0: 'Egypt',
#   10.0: 'Gabon',
#   11.0: 'Ghana',
#   12.0: 'Guinea',
#   13.0: 'Kenya',
#   14.0: 'Lesotho',
#   15.0: 'Liberia',
#   16.0: 'Madagascar',
#   17.0: 'Malawi',
#   18.0: 'Mali',
#   19.0: 'Mauritius',
#   20.0: 'Morocco',
#   21.0: 'Mozambique',
#   22.0: 'Namibia',
#   23.0: 'Niger',
#   24.0: 'Nigeria',
#   25.0: 'São Tomé and Príncipe',
#   26.0: 'Senegal',
#   27.0: 'Sierra Leone',
#   28.0: 'South Africa',
#   29.0: 'Sudan',
#   30.0: 'Swaziland',
#   31.0: 'Tanzania',
#   32.0: 'Togo',
#   33.0: 'Tunisia',
#   34.0: 'Uganda',
#   35.0: 'Zambia',
#   36.0: 'Zimbabwe',
#   37.0: 'Gambia'},
#  'COUNTRY.BY.REGION': {1.0: 'West Africa',
#   2.0: 'East Africa',
#   3.0: 'Southern Africa',
#   4.0: 'North Africa',
#   5.0: 'Central Africa'},
#  'URBRUR': {1.0: 'Urban',
#   2.0: 'Rural',
#   3.0: 'Semi-Urban',
#   460.0: 'Peri-Urban'},
#  'REGION': {100.0: 'Alibori',
#   101.0: 'Atacora',
#   102.0: 'Atlantique',
#   103.0: 'Borgou',
#   104.0: 'Collines',
#   105.0: 'Couffo',
#   106.0: 'Donga',
#   107.0: 'Littoral',
#   108.0: 'Mono',
#   109.0: 'Oueme',
#   110.0: 'Plateau',
#   111.0: 'Zou',
#   140.0: 'Barolong',
#   141.0: 'Central Bobonong',
#   142.0: 'Central Boteti/Orapa',
#   143.0: 'Central Mahalapye',
#   144.0: 'Central Serowe',
#   145.0: 'Central Tutume/Sowa Town',
#   146.0: 'Chobe',
#   147.0: 'Francistown',
#   148.0: 'Gaborone',
#   149.0: 'Ghanzi',
#   150.0: 'Jwaneng',
#   151.0: 'Kgalagadi North',
#   152.0: 'Kgalagadi South',
#   153.0: 'Kgatleng',
#   154.0: 'Kweneng East',
#   155.0: 'Kweneng West',
#   156.0: 'Lobatse',
#   157.0: 'Ngamiland East',
#   158.0: 'Ngamiland West',
#   159.0: 'Ngwaketse',
#   160.0: 'Ngwaketse West',
#   161.0: 'North East',
#   162.0: 'Selibe Phikwe',
#   163.0: 'South East',
#   180.0: 'Boucle Du Mouhoun',
#   181.0: 'Cascades',
#   182.0: 'Centre',
#   183.0: 'Centre Est',
#   184.0: 'Centre Nord',
#   185.0: 'Centre Ouest',
#   186.0: 'Centre Sud',
#   187.0: 'Est',
#   188.0: 'Hauts Bassins',
#   189.0: 'Nord',
#   190.0: 'Plateau Central',
#   191.0: 'Sahel',
#   192.0: 'Sud Ouest',
#   220.0: 'Santo Antão',
#   221.0: 'São Vicente',
#   222.0: 'Santiago – Interior',
#   223.0: 'Santiago – Praia',
#   224.0: 'Fogo',
#   260.0: 'Western',
#   261.0: 'Central',
#   262.0: 'Greater Accra',
#   263.0: 'Volta',
#   264.0: 'Eastern',
#   265.0: 'Ashanti',
#   266.0: 'Brong Ahafo',
#   267.0: 'Northern',
#   268.0: 'Upper East',
#   269.0: 'Upper West',
#   300.0: 'Nairobi',
#   301.0: 'Central',
#   302.0: 'Eastern',
#   303.0: 'Rift Valley',
#   304.0: 'Nyanza',
#   305.0: 'Western',
#   306.0: 'North Eastern',
#   307.0: 'Coast',
#   340.0: 'Maseru',
#   341.0: 'Mafeteng',
#   342.0: "Mohale's Hoek",
#   343.0: 'Quthing',
#   344.0: "Qacha's Nek",
#   345.0: 'Mokhotlong',
#   346.0: 'Botha-Bothe',
#   347.0: 'Leribe',
#   348.0: 'Berea',
#   349.0: 'Thaba-Tseka',
#   380.0: 'Bomi',
#   381.0: 'Bong',
#   382.0: 'Gbarpolu',
#   383.0: 'Grand Bassa',
#   384.0: 'Grand Cape Mount',
#   385.0: 'Grand Gedeh',
#   386.0: 'Grand Kru',
#   387.0: 'Lofa',
#   388.0: 'Margibi',
#   389.0: 'Maryland',
#   390.0: 'Montserrado',
#   391.0: 'Nimba',
#   392.0: 'River Cess',
#   393.0: 'River Gee',
#   394.0: 'Sinoe',
#   420.0: 'Alaotra Mangoro',
#   421.0: "Amoron'i Mania",
#   422.0: 'Analamanga',
#   423.0: 'Analanjirofo',
#   424.0: 'Androy',
#   425.0: 'Anosy',
#   426.0: 'Atsimo Andrefana',
#   427.0: 'Atsimo Atsinanana',
#   428.0: 'Atsinanana',
#   429.0: 'Betsiboka',
#   430.0: 'Boeny',
#   431.0: 'Bongolava',
#   432.0: 'Diana',
#   433.0: 'Haute Matsiatra',
#   434.0: 'Ihorombe',
#   435.0: 'Itasy',
#   436.0: 'Melaky',
#   437.0: 'Menabe',
#   438.0: 'Sava',
#   439.0: 'Sofia',
#   440.0: 'Vakinankaratra',
#   441.0: 'Vatovavy Fitovinany',
#   460.0: 'Northern Region',
#   461.0: 'Central Region',
#   462.0: 'Southern Region',
#   501.0: 'Kayes',
#   502.0: 'Koulikoro',
#   503.0: 'Sikasso',
#   504.0: 'Segou',
#   505.0: 'Mopti',
#   506.0: 'Tombouctou',
#   507.0: 'Gao',
#   508.0: 'Kidal',
#   509.0: 'Bamako',
#   540.0: 'Maputo Province',
#   541.0: 'Maputo City',
#   542.0: 'Gaza',
#   543.0: 'Inhambane',
#   544.0: 'Sofala',
#   545.0: 'Tete',
#   546.0: 'Manica',
#   547.0: 'Zambézia',
#   548.0: 'Nampula',
#   549.0: 'Cabo Delgado',
#   550.0: 'Niassa',
#   580.0: 'Zambezi',
#   581.0: 'Erongo',
#   582.0: 'Hardap',
#   583.0: 'Karas',
#   584.0: 'Kavango West',
#   585.0: 'Kavango East',
#   586.0: 'Khomas',
#   587.0: 'Kunene',
#   588.0: 'Ohangwena',
#   589.0: 'Omaheke',
#   590.0: 'Omusati',
#   591.0: 'Oshana',
#   592.0: 'Oshikoto',
#   593.0: 'Otjozondjupa',
#   620.0: 'Abia',
#   621.0: 'Adamawa',
#   622.0: 'Akwa Ibom',
#   623.0: 'Anambra',
#   624.0: 'Bauchi',
#   625.0: 'Bayelsa',
#   626.0: 'Benue',
#   627.0: 'Borno',
#   628.0: 'Cross River',
#   629.0: 'Delta',
#   630.0: 'Ebonyi',
#   631.0: 'Edo',
#   632.0: 'Ekiti',
#   633.0: 'Enugu',
#   634.0: 'Fct Abuja',
#   635.0: 'Gombe',
#   636.0: 'Imo',
#   637.0: 'Jigawa',
#   638.0: 'Kaduna',
#   639.0: 'Kano',
#   640.0: 'Katsina',
#   641.0: 'Kebbi',
#   642.0: 'Kogi',
#   643.0: 'Kwara',
#   644.0: 'Lagos',
#   645.0: 'Nasarawa',
#   646.0: 'Niger',
#   647.0: 'Ogun',
#   648.0: 'Ondo',
#   649.0: 'Osun',
#   650.0: 'Oyo',
#   651.0: 'Plateau',
#   652.0: 'Rivers',
#   653.0: 'Sokoto',
#   654.0: 'Taraba',
#   655.0: 'Yobe',
#   656.0: 'Zamfara',
#   660.0: 'Dakar',
#   661.0: 'Diourbel',
#   662.0: 'Fatick',
#   663.0: 'Kaffrine',
#   664.0: 'Kaolack',
#   665.0: 'Kédougou',
#   666.0: 'Kolda',
#   667.0: 'Louga',
#   668.0: 'Matam',
#   669.0: 'Saint-Louis',
#   670.0: 'Sédhiou',
#   671.0: 'Tambacounda',
#   672.0: 'Thies',
#   673.0: 'Ziguinchor',
#   700.0: 'Eastern Cape',
#   701.0: 'Free State',
#   702.0: 'Gauteng',
#   703.0: 'Kwazulu-Natal',
#   704.0: 'Limpopo',
#   705.0: 'Mpumalanga',
#   706.0: 'North West',
#   707.0: 'Northern Cape',
#   708.0: 'Western Cape',
#   740.0: 'Dodoma',
#   741.0: 'Arusha',
#   742.0: 'Kilimanjaro',
#   743.0: 'Tanga',
#   744.0: 'Morogoro',
#   745.0: 'Pwani',
#   746.0: 'Dar Es Salaam',
#   747.0: 'Lindi',
#   748.0: 'Mtwara',
#   749.0: 'Ruvuma',
#   750.0: 'Iringa',
#   751.0: 'Mbeya',
#   752.0: 'Singida',
#   753.0: 'Tabora',
#   754.0: 'Rukwa',
#   755.0: 'Kigoma',
#   756.0: 'Shinyanga',
#   757.0: 'Kagera',
#   758.0: 'Mwanza',
#   759.0: 'Mara',
#   760.0: 'Manyara',
#   761.0: 'Kaskazini Unguja',
#   762.0: 'Kusini Unguja',
#   763.0: 'Mjini Magharibi',
#   764.0: 'Kaskazini Pemba',
#   765.0: 'Kusini Pemba',
#   766.0: 'Geita',
#   767.0: 'Katavi',
#   768.0: 'Njombe',
#   769.0: 'Simiyu',
#   780.0: 'Acholi',
#   781.0: 'Lango',
#   782.0: 'Karamoja',
#   783.0: 'Eastern',
#   784.0: 'Busoga',
#   820.0: 'Lusaka',
#   821.0: 'Central',
#   822.0: 'Copperbelt',
#   823.0: 'Eastern',
#   824.0: 'Luapula',
#   825.0: 'Northern',
#   826.0: 'North Western',
#   827.0: 'Southern',
#   828.0: 'Western',
#   829.0: 'Muchinga',
#   860.0: 'Harare',
#   861.0: 'Bulawayo',
#   862.0: 'Midlands',
#   863.0: 'Masvingo',
#   864.0: 'Mashonaland East',
#   865.0: 'Mashonaland West',
#   866.0: 'Mashonaland Central',
#   867.0: 'Matabeleland South',
#   868.0: 'Matabeleland North',
#   869.0: 'Manicaland',
#   900.0: 'Port Louis',
#   901.0: 'Pamplemousses',
#   902.0: 'Riv Du Rempart',
#   903.0: 'Flacq',
#   904.0: 'Grand Port',
#   905.0: 'Savanne',
#   906.0: 'Plaine Wilhems',
#   907.0: 'Moka',
#   908.0: 'Black River',
#   909.0: 'Rodrigues',
#   930.0: 'Eastern Province',
#   931.0: 'Northern Province',
#   932.0: 'Southern Province',
#   933.0: 'Western Area',
#   1100.0: 'Agadez',
#   1101.0: 'Diffa',
#   1102.0: 'Dosso',
#   1103.0: 'Maradi',
#   1104.0: 'Tahoua',
#   1105.0: 'Tillaberi',
#   1106.0: 'Zinder',
#   1107.0: 'Niamey',
#   1140.0: 'Lome',
#   1141.0: 'Maritime',
#   1142.0: 'Plateaux',
#   1143.0: 'Centrale',
#   1144.0: 'Kara',
#   1145.0: 'Savanes',
#   1220.0: 'Mfoundi',
#   1221.0: 'Wouri',
#   1222.0: 'Adamaoua',
#   1223.0: 'Centre',
#   1224.0: 'Est',
#   1225.0: 'Extreme-Nord',
#   1226.0: 'Littoral',
#   1227.0: 'Nord',
#   1228.0: 'Nord Ouest',
#   1229.0: 'Ouest',
#   1230.0: 'Sud',
#   1231.0: 'Sud Ouest',
#   1260.0: "Autonome D'abidjan",
#   1261.0: 'Agneby-Tiassa',
#   1262.0: 'Bafing',
#   1263.0: 'Bagoue',
#   1264.0: 'Belier',
#   1265.0: 'Bere',
#   1266.0: 'Bounkani',
#   1267.0: 'Cavally',
#   1268.0: 'Folon',
#   1269.0: 'Gbeke',
#   1270.0: 'Gbôkle',
#   1271.0: 'Gôh',
#   1272.0: 'Gontougo',
#   1273.0: 'Grands-Ponts',
#   1274.0: 'Guemon',
#   1275.0: 'Hambol',
#   1276.0: 'Haut-Sassandra',
#   1277.0: 'Iffou',
#   1278.0: 'Indenie-Djuablin',
#   1279.0: 'Kabadougou',
#   1280.0: 'La Me',
#   1281.0: 'Lôh-Djiboua',
#   1282.0: 'Marahoue',
#   1283.0: 'Moronou',
#   1284.0: 'Nawa',
#   1285.0: "N'zi",
#   1286.0: 'Poro',
#   1287.0: 'San-Pedro',
#   1288.0: 'Sud-Comoe',
#   1289.0: 'Tchologo',
#   1290.0: 'Tonkpi',
#   1291.0: 'Worodougou',
#   1292.0: 'Autonome Yamoussoukro',
#   1300.0: 'Conakry',
#   1301.0: 'Boké',
#   1302.0: 'Kindia',
#   1303.0: 'Mamou',
#   1304.0: 'Labé',
#   1305.0: 'Faranah',
#   1306.0: 'Kankan',
#   1307.0: "N'zérékoré",
#   1501.0: 'BeniMellal-Khenifra',
#   1502.0: 'Deraa-Tafilalt',
#   1503.0: 'Dakhla-Ouad Eddahab',
#   1504.0: 'Fes-Meknes',
#   1505.0: 'Grand Casablanca-Settat',
#   1506.0: 'Guelmim-Ouadnoun',
#   1507.0: 'Laayoune-Sakiat Alhamra',
#   1508.0: 'Marrakech-Safi',
#   1509.0: 'Oriental',
#   1510.0: 'Rabat-Sale-Kenitra',
#   1511.0: 'Souss-Massa',
#   1512.0: 'Tangier-Tetouan-Hoceima',
#   1540.0: 'Middle East',
#   1541.0: 'North',
#   1542.0: 'Darfur',
#   1543.0: 'East',
#   1544.0: 'Khartoum',
#   1545.0: 'Kordofan',
#   1580.0: 'Great Tunis',
#   1581.0: 'North East',
#   1582.0: 'North West',
#   1583.0: 'Center East',
#   1584.0: 'Center West',
#   1585.0: 'South East',
#   1586.0: 'South West',
#   1620.0: 'Hhohho',
#   1621.0: 'Lubombo',
#   1622.0: 'Manzini',
#   1623.0: 'Shiselweni',
#   1660.0: 'São Tomé',
#   1661.0: 'Príncipe',
#   1700.0: 'Estuaire',
#   1701.0: 'Haut-Ogooué',
#   1702.0: 'Moyen-Ogooué',
#   1703.0: 'Ngounié',
#   1704.0: 'Nyanga',
#   1705.0: 'Ogooué-Ivindo',
#   1706.0: 'Ogooué_Lolo',
#   1707.0: 'Ogooué-Maritime',
#   1708.0: 'Woleu-Ntem',
#   1740.0: 'Banjul',
#   1741.0: 'Upper River',
#   1742.0: 'Central River - North',
#   1743.0: 'Central River - South',
#   1744.0: 'Lower River',
#   1745.0: 'North Bank',
#   1746.0: 'West Coast',
#   1747.0: 'Kanifing'},
#  'EA_SVC_A': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_SVC_B': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_SVC_C': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_SVC_D': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_FAC_A': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_FAC_B': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_FAC_C': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_FAC_D': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_FAC_E': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_FAC_F': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_FAC_G': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Can't determine"},
#  'EA_SEC_A': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Don't know"},
#  'EA_SEC_B': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Don't know"},
#  'EA_SEC_C': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Don't know"},
#  'EA_SEC_D': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Don't know"},
#  'EA_SEC_E': {-1.0: 'Missing', 0.0: 'No', 1.0: 'Yes', 9.0: "Don't know"},
#  'EA_ROAD_A': {-1.0: 'Missing',
#   1.0: 'Earth',
#   2.0: 'Gravel',
#   3.0: 'Stone',
#   4.0: 'Muram',
#   5.0: 'Paved/ Tarred',
#   6.0: 'Concrete'},
#  'EA_ROAD_B': {-1.0: 'Missing',
#   1.0: 'Earth',
#   2.0: 'Gravel',
#   3.0: 'Stone',
#   4.0: 'Muram',
#   5.0: 'Paved/ Tarred',
#   6.0: 'Concrete'},
#  'EA_ROAD_C': {-1.0: 'Missing',
#   1.0: 'Impassable',
#   2.0: 'Very poor',
#   3.0: 'Poor',
#   4.0: 'Fair',
#   5.0: 'Good',
#   6.0: 'Very good'},
#  'NOCALL_1': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'NOCALL_2': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'NOCALL_3': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'NOCALL_4': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'NOCALL_5': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'NOCALL_6': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'NOCALL_7': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'NOCALL_8': {1.0: 'Refused to be interviewed',
#   2.0: 'Person selected was never at home',
#   3.0: 'Household/Premises empty for the survey period',
#   4.0: 'Not a citizen/Spoke only a foreign language',
#   5.0: 'Deaf/Did not speak a survey language',
#   6.0: 'Did not fit gender quota',
#   7.0: 'No adults in household',
#   8.0: 'Other',
#   9997.0: 'Interview was successful'},
#  'THISINT': {-1.0: 'Missing', 1.0: 'Male', 2.0: 'Female'},
#  'Q1': {-1.0: 'Missing', 998.0: 'Refused', 999.0: "Don't know"},
#  'Q2A': {-1.0: 'Missing',
#   1.0: 'English',
#   2.0: 'French',
#   3.0: 'Portuguese',
#   4.0: 'Kiswahili',
#   100.0: 'Adjagbé',
#   101.0: 'Baatonum',
#   102.0: 'Dendi',
#   103.0: 'Ditammari',
#   104.0: 'Fongbé',
#   105.0: 'Fulfuldé',
#   106.0: 'Yoruba',
#   107.0: 'Lopka',
#   108.0: 'Waama',
#   109.0: 'Yom',
#   110.0: 'Gourmantché',
#   140.0: 'Setswana',
#   141.0: 'Sesarwa',
#   142.0: 'Sekgalagadi',
#   143.0: 'Sesubia',
#   144.0: 'Ikalanga/Sekalaka',
#   145.0: 'Seherero',
#   146.0: 'Sembukushu',
#   147.0: 'Sebirwa',
#   148.0: 'Sengologa',
#   149.0: 'Seyeyi',
#   150.0: 'Afrikaans/Seburu',
#   152.0: 'Setswapong',
#   180.0: 'Mooré',
#   181.0: 'Dioula',
#   182.0: 'Fulfudé',
#   183.0: 'Gulmacema',
#   184.0: 'Gourounsi',
#   185.0: 'Bissa',
#   186.0: 'Birifor',
#   187.0: 'Bwamu',
#   188.0: 'Dagari',
#   189.0: 'Fulse',
#   190.0: 'Goin',
#   191.0: 'Karaboro',
#   192.0: 'Kassena',
#   193.0: 'Lobi',
#   194.0: 'Marka',
#   195.0: 'Samo',
#   196.0: 'Sénoufo',
#   197.0: 'Sonraï',
#   198.0: 'Bobo',
#   199.0: 'Toussian',
#   200.0: 'Tamachek',
#   220.0: 'Crioulo',
#   221.0: 'Portuguese',
#   260.0: 'Akan',
#   261.0: 'Ewe/Anlo',
#   262.0: 'Ga/Dangbe',
#   263.0: 'Dagbani',
#   264.0: 'Dagaare',
#   265.0: 'Mamprusi',
#   266.0: 'Mampruli',
#   267.0: 'Kusaal',
#   268.0: 'Kotokoli',
#   269.0: 'Konkomba',
#   270.0: 'Hausa',
#   271.0: 'Gonja',
#   272.0: 'Frafra',
#   273.0: 'Builsa',
#   300.0: 'Kikuyu',
#   301.0: 'Luo',
#   302.0: 'Luhya',
#   303.0: 'Kamba',
#   304.0: 'Kalenjin',
#   305.0: 'Kisii',
#   306.0: 'Meru/Embu',
#   307.0: 'Masai/Samburu',
#   308.0: 'Mijikenda',
#   309.0: 'Taita',
#   310.0: 'Somali',
#   311.0: 'Pokot',
#   312.0: 'Turkana',
#   340.0: 'Sesotho',
#   341.0: 'Sephuthi',
#   342.0: 'Sethepu',
#   380.0: 'Bassa',
#   381.0: 'Belle',
#   382.0: 'Dei',
#   383.0: 'Gbandi',
#   384.0: 'Gio',
#   385.0: 'Gola',
#   386.0: 'Grebo',
#   387.0: 'Kissi',
#   388.0: 'Kpelle',
#   389.0: 'Krahn',
#   390.0: 'Kru',
#   391.0: 'Lorma',
#   392.0: 'Mandingo',
#   393.0: 'Mano',
#   394.0: 'Mende',
#   395.0: 'Vai',
#   396.0: 'Liberian English',
#   420.0: '"Official" Malagasy',
#   421.0: 'Malagasy With Regional Dialect',
#   422.0: 'Chinese',
#   460.0: 'Chitumbuka',
#   461.0: 'Chinkhonde',
#   462.0: 'Chilambya',
#   463.0: 'Chichewa',
#   464.0: 'Chiyao',
#   465.0: 'Chingoni',
#   466.0: 'Chilomwe',
#   467.0: 'Chimang’anja',
#   468.0: 'Chisena',
#   470.0: 'Chisenga',
#   471.0: 'Chitonga',
#   500.0: 'Arabe',
#   501.0: 'Bambara',
#   502.0: 'Bella',
#   503.0: 'Bobo',
#   504.0: 'Bozo',
#   505.0: 'Dogon',
#   507.0: 'Kakolo',
#   508.0: 'Khassonké',
#   509.0: 'Malinké',
#   510.0: 'Maure',
#   511.0: 'Minianka',
#   512.0: 'Mossi',
#   513.0: 'Peulh / Fulfude',
#   515.0: 'Senufo',
#   516.0: 'Soninké / Sarakollé',
#   517.0: 'Sonrhaï',
#   518.0: 'Tamasheq',
#   540.0: 'Makua',
#   541.0: 'Sena',
#   542.0: 'Ndau',
#   543.0: 'Changana',
#   544.0: 'Nyanja',
#   545.0: 'Chope',
#   546.0: 'Bitonga',
#   547.0: 'Makonde',
#   548.0: 'Chuabo',
#   549.0: 'Ajaua',
#   550.0: 'Lomue',
#   551.0: 'Shona',
#   552.0: 'Xitswa',
#   553.0: 'Xironga',
#   554.0: 'Chichewa',
#   555.0: 'Cinyungwe',
#   556.0: 'Ciyao',
#   557.0: 'Ekoti',
#   558.0: 'Kimwani',
#   559.0: 'Nhungue',
#   560.0: 'Manhaua',
#   580.0: 'Afrikaans',
#   581.0: 'German',
#   582.0: 'Nama/Damara',
#   583.0: 'Oshiwambo (Oshindonga/Oshikwanyama)',
#   584.0: 'Otjiherero',
#   585.0: 'Rukwangali',
#   586.0: 'Rugririku/Rumanyo',
#   587.0: 'Thimbukushu',
#   588.0: 'Silozi',
#   589.0: 'Setswana',
#   590.0: 'Masubia',
#   620.0: 'Hausa',
#   621.0: 'Igbo',
#   622.0: 'Yoruba',
#   624.0: 'Efik',
#   625.0: 'Ebira',
#   626.0: 'Fulani',
#   627.0: 'Isoko',
#   628.0: 'Ibibio',
#   629.0: 'Kanuri',
#   630.0: 'Tiv',
#   631.0: 'Nupe',
#   632.0: 'Ijaw',
#   633.0: 'Edo',
#   634.0: 'Igala',
#   635.0: 'Urhobo',
#   636.0: 'Ogoni',
#   637.0: 'Anang',
#   638.0: 'Ikwere',
#   639.0: 'Idoma',
#   640.0: 'Esan',
#   641.0: 'Nembe',
#   642.0: 'Aten',
#   643.0: 'Higgi',
#   644.0: 'Kurama',
#   645.0: 'Waja',
#   660.0: 'Wolof',
#   661.0: 'Pulaar/Toucouleur',
#   662.0: 'Serer',
#   663.0: 'Mandinka/Bambara',
#   664.0: 'Soninke',
#   665.0: 'Diola',
#   666.0: 'Manjack',
#   667.0: 'Bainouk',
#   668.0: 'Bassari',
#   700.0: 'Afrikaans',
#   701.0: 'Ndebele',
#   702.0: 'Xhosa',
#   703.0: 'Pedi/North Sotho',
#   704.0: 'Sotho/South Sotho',
#   705.0: 'Tswana',
#   706.0: 'Shangaan/Tsonga',
#   707.0: 'Swazi',
#   708.0: 'Venda',
#   709.0: 'Zulu',
#   740.0: 'Kinyakyusa',
#   741.0: 'Kichaga',
#   742.0: 'Kihaya',
#   743.0: 'Kingoni',
#   744.0: 'Kikwere',
#   745.0: 'Kipare',
#   746.0: 'Kihehe',
#   747.0: 'Kimakonde',
#   748.0: 'Kinyamwezi',
#   749.0: 'Kisukuma',
#   750.0: 'Kimasai',
#   751.0: 'Kimeru',
#   752.0: 'Kikurya',
#   753.0: 'Kigogo',
#   754.0: 'Kiluguru',
#   755.0: 'Kifipa',
#   756.0: 'Kimanyema',
#   757.0: 'Kinyiramba',
#   758.0: 'Kinyaturu',
#   759.0: 'Kibena',
#   760.0: 'Kidigo',
#   761.0: 'Kiha',
#   762.0: 'Kijaluo',
#   763.0: 'Kijita',
#   764.0: 'Kikaguru',
#   765.0: 'Kikerewe',
#   766.0: 'Kikinga',
#   767.0: 'Kimambwe',
#   768.0: 'Kimatengo',
#   769.0: 'Kimbulu',
#   770.0: 'Kimwera',
#   771.0: 'Kindali',
#   772.0: 'Kindengereko',
#   773.0: 'Kingindo',
#   774.0: 'Kinyamwanga',
#   775.0: 'Kinyiha',
#   776.0: 'Kipogoro',
#   777.0: 'Kirangi',
#   778.0: 'Kisambaa',
#   779.0: 'Kishirazi',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   800.0: 'Kakwa',
#   801.0: 'Rufumbira',
#   820.0: 'Bemba',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   831.0: 'Bisa',
#   832.0: 'Nkoya',
#   833.0: 'Mambwe',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   836.0: 'Soli',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   839.0: 'Chokwe',
#   840.0: 'Mbunda',
#   841.0: 'Kunda',
#   842.0: 'Lala',
#   843.0: 'Lamba',
#   844.0: 'Lungu',
#   845.0: 'Nyika',
#   846.0: 'Senga',
#   847.0: 'Tokaleya',
#   849.0: 'Ngumbo',
#   851.0: 'Tabwa',
#   860.0: 'Ndebele',
#   861.0: 'Shona',
#   862.0: 'Zezuru',
#   863.0: 'Korekore',
#   864.0: 'Karanga',
#   865.0: 'Manyika',
#   866.0: 'Ndau',
#   867.0: 'Venda',
#   868.0: 'Kalanga',
#   869.0: 'Tonga',
#   870.0: 'Buja',
#   871.0: 'Chewa',
#   900.0: 'Creole',
#   901.0: 'Bhojpuri',
#   930.0: 'Krio',
#   931.0: 'Mende',
#   932.0: 'Temne',
#   933.0: 'Limba',
#   934.0: 'Loko',
#   935.0: 'Sherbro',
#   936.0: 'Fulla',
#   937.0: 'Kono',
#   938.0: 'Kuranko',
#   939.0: 'Madingo',
#   940.0: 'Vai',
#   941.0: 'Susu',
#   942.0: 'Kru',
#   943.0: 'Yalunka',
#   944.0: 'Kissi',
#   1100.0: 'Haoussa',
#   1101.0: 'Zarma/Songhay',
#   1102.0: 'Fulfulde',
#   1103.0: 'Tamasheq',
#   1104.0: 'Kanouri',
#   1106.0: 'Arabe',
#   1107.0: 'Toubou',
#   1140.0: 'Ewé',
#   1141.0: 'Mina (Guen)',
#   1142.0: 'Kabyè',
#   1143.0: 'Tem (Kotokoli)',
#   1144.0: 'Ben (Moba)',
#   1145.0: 'Nawdem (Losso)',
#   1146.0: 'Lama (Lamba)',
#   1147.0: 'Ifè (Ana)',
#   1148.0: 'Ikposso (Akposso)',
#   1149.0: 'N’tcha (Bassar)',
#   1150.0: 'Adja',
#   1151.0: 'Akébou',
#   1152.0: 'Gourma',
#   1153.0: 'Konkomba',
#   1154.0: 'Ngam-Gam',
#   1155.0: 'Tchamba',
#   1156.0: 'Fon',
#   1157.0: 'Ouatchi',
#   1159.0: 'Haoussa',
#   1160.0: 'Tchokossi (Anoufom)',
#   1220.0: 'Foufouldé',
#   1221.0: 'Pidgin',
#   1222.0: 'Ewondo',
#   1223.0: 'Bafang',
#   1224.0: 'Douala',
#   1225.0: 'Bafia',
#   1226.0: 'Bafut',
#   1227.0: 'Bagangte',
#   1228.0: 'Bakundu',
#   1229.0: 'Bamileke',
#   1230.0: 'Bamoun',
#   1231.0: 'Bandjoun',
#   1232.0: 'Bangwa',
#   1233.0: 'Banso',
#   1234.0: 'Bassa',
#   1235.0: 'Batanga',
#   1236.0: 'Bayangi',
#   1237.0: 'Bula',
#   1238.0: 'Dschang',
#   1239.0: 'Eton',
#   1240.0: 'Fali',
#   1241.0: 'Fong',
#   1242.0: 'Gbaya',
#   1243.0: 'Guider',
#   1244.0: 'Guiziga',
#   1245.0: 'Haoussa',
#   1246.0: 'Kapsiki',
#   1247.0: 'Mafa',
#   1248.0: 'Maka',
#   1249.0: 'Mankon',
#   1250.0: 'Massa',
#   1251.0: 'Mbouda',
#   1252.0: 'Mboum',
#   1253.0: 'Mobakoh',
#   1254.0: 'Moudan',
#   1255.0: 'Ngueba',
#   1256.0: 'Njikwa',
#   1257.0: 'Lamnso',
#   1259.0: 'Toupouri',
#   1260.0: 'Abbey',
#   1261.0: 'Abron',
#   1262.0: 'Adjoukrou',
#   1263.0: 'Agny',
#   1264.0: 'Attié',
#   1265.0: 'Avikam',
#   1266.0: 'Bambara',
#   1267.0: 'Baoulé',
#   1268.0: 'Bété',
#   1269.0: 'Dida',
#   1270.0: 'Dioula',
#   1271.0: 'Godié',
#   1272.0: 'Gouro',
#   1273.0: 'Guéré',
#   1274.0: 'Koulango',
#   1275.0: 'Kroumen',
#   1276.0: 'Lobi',
#   1277.0: 'Malinké / Dioula',
#   1278.0: 'Sénoufo',
#   1279.0: 'Yacouba',
#   1280.0: 'Djimini',
#   1281.0: 'Ebrié',
#   1282.0: 'Koyaka',
#   1283.0: 'Tagbana',
#   1300.0: 'Mano',
#   1301.0: 'Maninka',
#   1302.0: 'Loma',
#   1303.0: 'Kpèlè',
#   1304.0: 'Kissié',
#   1305.0: 'Poular',
#   1306.0: 'Sossou',
#   1500.0: 'Arabic',
#   1501.0: 'Amazigh',
#   1502.0: 'Moroccan Arabic',
#   1503.0: 'Hassani',
#   1504.0: 'Northern',
#   1540.0: 'Sudanese Arabic',
#   1541.0: 'Nubian Language',
#   1543.0: 'Beja Language',
#   1580.0: 'Arabic',
#   1581.0: 'Berber Language',
#   1582.0: 'Tunisian Arabic',
#   1620.0: 'Siswati',
#   1621.0: 'Zulu',
#   1660.0: 'Crioulo',
#   1661.0: 'Forro',
#   1662.0: 'Angular',
#   1700.0: 'Fang',
#   1701.0: 'Punu/Mériè',
#   1702.0: 'Kota',
#   1703.0: 'Mbédè',
#   1704.0: 'Nzébi/Métié',
#   1705.0: 'Myénè',
#   1706.0: 'Tsogho',
#   1707.0: 'Kélé',
#   1708.0: 'Bakanigui',
#   1709.0: 'Baloumbou',
#   1710.0: 'Bateke',
#   1711.0: 'Bavungu',
#   1712.0: 'Eshira',
#   1713.0: 'Masangu',
#   1714.0: 'Miene',
#   1715.0: 'Obamba',
#   1716.0: 'Vili',
#   1740.0: 'Fula',
#   1741.0: 'Wolof',
#   1742.0: 'Jola',
#   1743.0: 'Mandinka',
#   1744.0: 'Manjago',
#   1745.0: 'Serahuleh',
#   1746.0: 'Serer',
#   1747.0: 'Jahanka',
#   2220.0: 'Yamba',
#   2221.0: 'Yabassi',
#   2223.0: 'Mousgoum',
#   2224.0: 'Banen',
#   2226.0: 'Daba',
#   2227.0: 'Yemba',
#   2228.0: 'Yambassa',
#   2231.0: 'Djimi',
#   2740.0: 'Kitumbatu',
#   2741.0: 'Kiyao',
#   2742.0: 'Kizaramo',
#   2743.0: 'Kizigua',
#   2744.0: 'Mzigua',
#   9995.0: 'Other',
#   9998.0: 'Refused To Answer',
#   9999.0: "Don't know"},
#  'Q2B': {-1.0: 'Missing',
#   1.0: 'English',
#   2.0: 'French',
#   3.0: 'Portuguese',
#   4.0: 'Kiswahili',
#   100.0: 'Adjagbé',
#   101.0: 'Baatonum',
#   102.0: 'Dendi',
#   103.0: 'Ditammari',
#   104.0: 'Fongbé',
#   105.0: 'Fulfuldé',
#   106.0: 'Yoruba',
#   107.0: 'Lopka',
#   108.0: 'Waama',
#   109.0: 'Yom',
#   110.0: 'Gourmantché',
#   111.0: 'Torigbe',
#   140.0: 'Setswana',
#   141.0: 'Sesarwa',
#   142.0: 'Sekgalagadi',
#   143.0: 'Sesubia',
#   144.0: 'Ikalanga/Sekalaka',
#   145.0: 'Seherero',
#   146.0: 'Sembukushu',
#   147.0: 'Sebirwa',
#   148.0: 'Sengologa',
#   149.0: 'Seyeyi',
#   150.0: 'Afrikaans/Seburu',
#   152.0: 'Setswapong',
#   180.0: 'Mooré',
#   181.0: 'Dioula',
#   182.0: 'Fulfudé',
#   183.0: 'Gulmacema',
#   184.0: 'Gourounsi',
#   185.0: 'Bissa',
#   186.0: 'Birifor',
#   187.0: 'Bwamu',
#   188.0: 'Dagari',
#   189.0: 'Fulse',
#   190.0: 'Goin',
#   191.0: 'Karaboro',
#   192.0: 'Kassena',
#   193.0: 'Lobi',
#   194.0: 'Marka',
#   195.0: 'Samo',
#   196.0: 'Sénoufo',
#   197.0: 'Sonraï',
#   198.0: 'Bobo',
#   199.0: 'Toussian',
#   200.0: 'Tamachek',
#   220.0: 'Crioulo',
#   221.0: 'Portuguese',
#   260.0: 'Akan',
#   261.0: 'Ewe/Anlo',
#   262.0: 'Ga/Dangbe',
#   263.0: 'Dagbani',
#   264.0: 'Dagaare',
#   265.0: 'Mamprusi',
#   266.0: 'Mampruli',
#   267.0: 'Kusaal',
#   268.0: 'Kotokoli',
#   269.0: 'Konkomba',
#   270.0: 'Hausa',
#   271.0: 'Gonja',
#   272.0: 'Frafra',
#   273.0: 'Builsa',
#   300.0: 'Kikuyu',
#   301.0: 'Luo',
#   302.0: 'Luhya',
#   303.0: 'Kamba',
#   304.0: 'Kalenjin',
#   305.0: 'Kisii',
#   306.0: 'Meru/Embu',
#   307.0: 'Masai/Samburu',
#   308.0: 'Mijikenda',
#   309.0: 'Taita',
#   310.0: 'Somali',
#   311.0: 'Pokot',
#   312.0: 'Turkana',
#   340.0: 'Sesotho',
#   341.0: 'Sephuthi',
#   342.0: 'Sethepu',
#   380.0: 'Bassa',
#   381.0: 'Belle',
#   382.0: 'Dei',
#   383.0: 'Gbandi',
#   384.0: 'Gio',
#   385.0: 'Gola',
#   386.0: 'Grebo',
#   387.0: 'Kissi',
#   388.0: 'Kpelle',
#   389.0: 'Krahn',
#   390.0: 'Kru',
#   391.0: 'Lorma',
#   392.0: 'Mandingo',
#   393.0: 'Mano',
#   394.0: 'Mende',
#   395.0: 'Vai',
#   396.0: 'Liberian English',
#   420.0: '"Official" Malagasy',
#   421.0: 'Malagasy With Regional Dialect',
#   422.0: 'Chinese',
#   460.0: 'Chitumbuka',
#   461.0: 'Chinkhonde',
#   462.0: 'Chilambya',
#   463.0: 'Chichewa',
#   464.0: 'Chiyao',
#   465.0: 'Chingoni',
#   466.0: 'Chilomwe',
#   467.0: 'Chimang’anja',
#   468.0: 'Chisena',
#   469.0: 'Chisukwa',
#   470.0: 'Chisenga',
#   471.0: 'Chitonga',
#   500.0: 'Arabe',
#   501.0: 'Bambara',
#   502.0: 'Bella',
#   503.0: 'Bobo',
#   504.0: 'Bozo',
#   505.0: 'Dogon',
#   506.0: 'Haoussa',
#   507.0: 'Kakolo',
#   508.0: 'Khassonké',
#   509.0: 'Malinké',
#   510.0: 'Maure',
#   511.0: 'Minianka',
#   512.0: 'Mossi',
#   513.0: 'Peulh / Fulfude',
#   515.0: 'Senufo',
#   516.0: 'Soninké / Sarakollé',
#   517.0: 'Sonrhaï',
#   518.0: 'Tamasheq',
#   540.0: 'Makua',
#   541.0: 'Sena',
#   542.0: 'Ndau',
#   543.0: 'Changana',
#   544.0: 'Nyanja',
#   545.0: 'Chope',
#   546.0: 'Bitonga',
#   547.0: 'Makonde',
#   548.0: 'Chuabo',
#   549.0: 'Ajaua',
#   550.0: 'Lomue',
#   551.0: 'Shona',
#   552.0: 'Xitswa',
#   553.0: 'Xironga',
#   554.0: 'Chichewa',
#   555.0: 'Cinyungwe',
#   556.0: 'Ciyao',
#   557.0: 'Ekoti',
#   558.0: 'Kimwani',
#   559.0: 'Nhungue',
#   560.0: 'Manhaua',
#   580.0: 'Afrikaans',
#   581.0: 'German',
#   582.0: 'Nama/Damara',
#   583.0: 'Oshiwambo (Oshindonga/Oshikwanyama)',
#   584.0: 'Otjiherero',
#   585.0: 'Rukwangali',
#   586.0: 'Rugririku/Rumanyo',
#   587.0: 'Thimbukushu',
#   588.0: 'Silozi',
#   589.0: 'Setswana',
#   590.0: 'Masubia',
#   620.0: 'Hausa',
#   621.0: 'Igbo',
#   622.0: 'Yoruba',
#   623.0: 'Pidgin English',
#   624.0: 'Efik',
#   625.0: 'Ebira',
#   626.0: 'Fulani',
#   627.0: 'Isoko',
#   628.0: 'Ibibio',
#   629.0: 'Kanuri',
#   630.0: 'Tiv',
#   631.0: 'Nupe',
#   632.0: 'Ijaw',
#   633.0: 'Edo',
#   634.0: 'Igala',
#   635.0: 'Urhobo',
#   636.0: 'Ogoni',
#   637.0: 'Anang',
#   638.0: 'Ikwere',
#   639.0: 'Idoma',
#   640.0: 'Esan',
#   641.0: 'Nembe',
#   642.0: 'Aten',
#   643.0: 'Higgi',
#   644.0: 'Kurama',
#   645.0: 'Waja',
#   660.0: 'Wolof',
#   661.0: 'Pulaar/Toucouleur',
#   662.0: 'Serer',
#   663.0: 'Mandinka/Bambara',
#   664.0: 'Soninke',
#   665.0: 'Diola',
#   666.0: 'Manjack',
#   667.0: 'Bainouk',
#   668.0: 'Bassari',
#   700.0: 'Afrikaans',
#   701.0: 'Ndebele',
#   702.0: 'Xhosa',
#   703.0: 'Pedi/North Sotho',
#   704.0: 'Sotho/South Sotho',
#   705.0: 'Tswana',
#   706.0: 'Shangaan/Tsonga',
#   707.0: 'Swazi',
#   708.0: 'Venda',
#   709.0: 'Zulu',
#   740.0: 'Kinyakyusa',
#   741.0: 'Kichaga',
#   742.0: 'Kihaya',
#   743.0: 'Kingoni',
#   744.0: 'Kikwere',
#   745.0: 'Kipare',
#   746.0: 'Kihehe',
#   747.0: 'Kimakonde',
#   748.0: 'Kinyamwezi',
#   749.0: 'Kisukuma',
#   750.0: 'Kimasai',
#   751.0: 'Kimeru',
#   752.0: 'Kikurya',
#   753.0: 'Kigogo',
#   754.0: 'Kiluguru',
#   755.0: 'Kifipa',
#   756.0: 'Kimanyema',
#   757.0: 'Kinyiramba',
#   758.0: 'Kinyaturu',
#   759.0: 'Kibena',
#   760.0: 'Kidigo',
#   761.0: 'Kiha',
#   762.0: 'Kijaluo',
#   763.0: 'Kijita',
#   764.0: 'Kikaguru',
#   765.0: 'Kikerewe',
#   766.0: 'Kikinga',
#   767.0: 'Kimambwe',
#   768.0: 'Kimatengo',
#   769.0: 'Kimbulu',
#   770.0: 'Kimwera',
#   771.0: 'Kindali',
#   772.0: 'Kindengereko',
#   773.0: 'Kingindo',
#   774.0: 'Kinyamwanga',
#   775.0: 'Kinyiha',
#   776.0: 'Kipogoro',
#   777.0: 'Kirangi',
#   778.0: 'Kisambaa',
#   779.0: 'Kishirazi',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   800.0: 'Kakwa',
#   801.0: 'Rufumbira',
#   820.0: 'Bemba',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   831.0: 'Bisa',
#   832.0: 'Nkoya',
#   833.0: 'Mambwe',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   836.0: 'Soli',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   839.0: 'Chokwe',
#   840.0: 'Mbunda',
#   841.0: 'Kunda',
#   842.0: 'Lala',
#   843.0: 'Lamba',
#   844.0: 'Lungu',
#   845.0: 'Nyika',
#   846.0: 'Senga',
#   847.0: 'Tokaleya',
#   849.0: 'Ngumbo',
#   851.0: 'Tabwa',
#   860.0: 'Ndebele',
#   861.0: 'Shona',
#   862.0: 'Zezuru',
#   863.0: 'Korekore',
#   864.0: 'Karanga',
#   865.0: 'Manyika',
#   866.0: 'Ndau',
#   867.0: 'Venda',
#   868.0: 'Kalanga',
#   869.0: 'Tonga',
#   870.0: 'Buja',
#   871.0: 'Chewa',
#   900.0: 'Creole',
#   901.0: 'Bhojpuri',
#   930.0: 'Krio',
#   931.0: 'Mende',
#   932.0: 'Temne',
#   933.0: 'Limba',
#   934.0: 'Loko',
#   935.0: 'Sherbro',
#   936.0: 'Fulla',
#   937.0: 'Kono',
#   938.0: 'Kuranko',
#   939.0: 'Madingo',
#   940.0: 'Vai',
#   941.0: 'Susu',
#   942.0: 'Kru',
#   943.0: 'Yalunka',
#   944.0: 'Kissi',
#   1100.0: 'Haoussa',
#   1101.0: 'Zarma/Songhay',
#   1102.0: 'Fulfulde',
#   1103.0: 'Tamasheq',
#   1104.0: 'Kanouri',
#   1106.0: 'Arabe',
#   1107.0: 'Toubou',
#   1140.0: 'Ewé',
#   1141.0: 'Mina (Guen)',
#   1142.0: 'Kabyè',
#   1143.0: 'Tem (Kotokoli)',
#   1144.0: 'Ben (Moba)',
#   1145.0: 'Nawdem (Losso)',
#   1146.0: 'Lama (Lamba)',
#   1147.0: 'Ifè (Ana)',
#   1148.0: 'Ikposso (Akposso)',
#   1149.0: 'N’tcha (Bassar)',
#   1150.0: 'Adja',
#   1151.0: 'Akébou',
#   1152.0: 'Gourma',
#   1153.0: 'Konkomba',
#   1154.0: 'Ngam-Gam',
#   1155.0: 'Tchamba',
#   1156.0: 'Fon',
#   1157.0: 'Ouatchi',
#   1158.0: 'Aklobo',
#   1159.0: 'Haoussa',
#   1160.0: 'Tchokossi (Anoufom)',
#   1220.0: 'Foufouldé',
#   1221.0: 'Pidgin',
#   1222.0: 'Ewondo',
#   1223.0: 'Bafang',
#   1224.0: 'Douala',
#   1225.0: 'Bafia',
#   1226.0: 'Bafut',
#   1227.0: 'Bagangte',
#   1228.0: 'Bakundu',
#   1229.0: 'Bamileke',
#   1230.0: 'Bamoun',
#   1231.0: 'Bandjoun',
#   1232.0: 'Bangwa',
#   1233.0: 'Banso',
#   1234.0: 'Bassa',
#   1235.0: 'Batanga',
#   1236.0: 'Bayangi',
#   1237.0: 'Bula',
#   1238.0: 'Dschang',
#   1239.0: 'Eton',
#   1240.0: 'Fali',
#   1241.0: 'Fong',
#   1242.0: 'Gbaya',
#   1243.0: 'Guider',
#   1244.0: 'Guiziga',
#   1245.0: 'Haoussa',
#   1246.0: 'Kapsiki',
#   1247.0: 'Mafa',
#   1248.0: 'Maka',
#   1249.0: 'Mankon',
#   1250.0: 'Massa',
#   1251.0: 'Mbouda',
#   1252.0: 'Mboum',
#   1253.0: 'Mobakoh',
#   1254.0: 'Moudan',
#   1255.0: 'Ngueba',
#   1256.0: 'Njikwa',
#   1257.0: 'Lamnso',
#   1258.0: 'Tikari',
#   1259.0: 'Toupouri',
#   1260.0: 'Abbey',
#   1261.0: 'Abron',
#   1262.0: 'Adjoukrou',
#   1263.0: 'Agny',
#   1264.0: 'Attié',
#   1265.0: 'Avikam',
#   1266.0: 'Bambara',
#   1267.0: 'Baoulé',
#   1268.0: 'Bété',
#   1269.0: 'Dida',
#   1270.0: 'Dioula',
#   1271.0: 'Godié',
#   1272.0: 'Gouro',
#   1273.0: 'Guéré',
#   1274.0: 'Koulango',
#   1275.0: 'Kroumen',
#   1276.0: 'Lobi',
#   1277.0: 'Malinké / Dioula',
#   1278.0: 'Sénoufo',
#   1279.0: 'Yacouba',
#   1280.0: 'Djimini',
#   1281.0: 'Ebrié',
#   1282.0: 'Koyaka',
#   1283.0: 'Tagbana',
#   1300.0: 'Mano',
#   1301.0: 'Maninka',
#   1302.0: 'Loma',
#   1303.0: 'Kpèlè',
#   1304.0: 'Kissié',
#   1305.0: 'Poular',
#   1306.0: 'Sossou',
#   1500.0: 'Arabic',
#   1501.0: 'Amazigh',
#   1502.0: 'Moroccan Arabic',
#   1503.0: 'Hassani',
#   1504.0: 'Northern',
#   1540.0: 'Sudanese Arabic',
#   1541.0: 'Nubian Language',
#   1543.0: 'Beja Language',
#   1580.0: 'Arabic',
#   1581.0: 'Berber Language',
#   1582.0: 'Tunisian Arabic',
#   1620.0: 'Siswati',
#   1621.0: 'Zulu',
#   1660.0: 'Crioulo',
#   1661.0: 'Forro',
#   1662.0: 'Angular',
#   1700.0: 'Fang',
#   1701.0: 'Punu/Mériè',
#   1702.0: 'Kota',
#   1703.0: 'Mbédè',
#   1704.0: 'Nzébi/Métié',
#   1705.0: 'Myénè',
#   1706.0: 'Tsogho',
#   1707.0: 'Kélé',
#   1708.0: 'Bakanigui',
#   1709.0: 'Baloumbou',
#   1710.0: 'Bateke',
#   1711.0: 'Bavungu',
#   1712.0: 'Eshira',
#   1713.0: 'Masangu',
#   1714.0: 'Miene',
#   1715.0: 'Obamba',
#   1716.0: 'Vili',
#   1740.0: 'Fula',
#   1741.0: 'Wolof',
#   1742.0: 'Jola',
#   1743.0: 'Mandinka',
#   1744.0: 'Manjago',
#   1745.0: 'Serahuleh',
#   1746.0: 'Serer',
#   1747.0: 'Jahanka',
#   2220.0: 'Yamba',
#   2221.0: 'Yabassi',
#   2223.0: 'Mousgoum',
#   2224.0: 'Banen',
#   2226.0: 'Daba',
#   2227.0: 'Yemba',
#   2228.0: 'Yambassa',
#   2231.0: 'Djimi',
#   2740.0: 'Kitumbatu',
#   2741.0: 'Kiyao',
#   2742.0: 'Kizaramo',
#   2743.0: 'Kizigua',
#   2744.0: 'Mzigua',
#   9995.0: 'Other',
#   9998.0: 'Refused To Answer',
#   9999.0: "Don't know"},
#  'Q3': {-1.0: 'Missing',
#   1.0: 'Going in the wrong direction',
#   2.0: 'Going in the right direction',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q4A': {-1.0: 'Missing',
#   1.0: 'Very Bad',
#   2.0: 'Fairly Bad',
#   3.0: 'Neither good nor bad',
#   4.0: 'Fairly Good',
#   5.0: 'Very good',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q4B': {-1.0: 'Missing',
#   1.0: 'Very Bad',
#   2.0: 'Fairly Bad',
#   3.0: 'Neither good nor bad',
#   4.0: 'Fairly Good',
#   5.0: 'Very good',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q5': {-1.0: 'Missing',
#   1.0: 'Much worse',
#   2.0: 'Worse',
#   3.0: 'Same',
#   4.0: 'Better',
#   5.0: 'Much better',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q6': {-1.0: 'Missing',
#   1.0: 'Much worse',
#   2.0: 'Worse',
#   3.0: 'Same',
#   4.0: 'Better',
#   5.0: 'Much better',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q7': {-1.0: 'Missing',
#   1.0: 'Much worse',
#   2.0: 'Worse',
#   3.0: 'Same',
#   4.0: 'Better',
#   5.0: 'Much better',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q8A': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Just once or twice',
#   2.0: 'Several times',
#   3.0: 'Many times',
#   4.0: 'Always',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q8B': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Just once or twice',
#   2.0: 'Several times',
#   3.0: 'Many times',
#   4.0: 'Always',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q8C': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Just once or twice',
#   2.0: 'Several times',
#   3.0: 'Many times',
#   4.0: 'Always',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q8D': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Just once or twice',
#   2.0: 'Several times',
#   3.0: 'Many times',
#   4.0: 'Always',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q8E': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Just once or twice',
#   2.0: 'Several times',
#   3.0: 'Many times',
#   4.0: 'Always',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q8F': {-1.0: 'Missing',
#   1.0: 'About once every two or three months',
#   2.0: 'About once a month',
#   3.0: 'Two or three times a month',
#   4.0: 'About once a week',
#   5.0: 'Several times a week',
#   6.0: 'Every day',
#   7.0: 'Not applicable',
#   8.0: 'Refused',
#   9.0: 'Don’t Know'},
#  'Q9': {-1.0: 'Missing',
#   0.0: 'Not at all / Does not receive remittances',
#   1.0: 'A little bit',
#   2.0: 'Somewhat',
#   3.0: 'A lot',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q10A': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Just once or twice',
#   2.0: 'Several times',
#   3.0: 'Many times',
#   4.0: 'Always',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q10B': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Just once or twice',
#   2.0: 'Several times',
#   3.0: 'Many times',
#   4.0: 'Always',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q11A': {-1.0: 'Missing',
#   0.0: 'No',
#   1.0: 'Yes, once',
#   2.0: 'Yes, twice',
#   3.0: 'Yes, three or more times',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q11B': {-1.0: 'Missing',
#   0.0: 'No',
#   1.0: 'Yes, once',
#   2.0: 'Yes, twice',
#   3.0: 'Yes, three or more times',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q12A': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Less than once a month',
#   2.0: 'A few times a month',
#   3.0: 'A few times a week',
#   4.0: 'Every day',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q12B': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Less than once a month',
#   2.0: 'A few times a month',
#   3.0: 'A few times a week',
#   4.0: 'Every day',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q12C': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Less than once a month',
#   2.0: 'A few times a month',
#   3.0: 'A few times a week',
#   4.0: 'Every day',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q12D': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Less than once a month',
#   2.0: 'A few times a month',
#   3.0: 'A few times a week',
#   4.0: 'Every day',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q12E': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Less than once a month',
#   2.0: 'A few times a month',
#   3.0: 'A few times a week',
#   4.0: 'Every day',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q13': {-1.0: 'Missing',
#   0.0: 'Never',
#   1.0: 'Occasionally',
#   2.0: 'Frequently',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q14': {-1.0: 'Missing',
#   1.0: 'Not at all free',
#   2.0: 'Not very free',
#   3.0: 'Somewhat free',
#   4.0: 'Completely free',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q15': {-1.0: 'Missing',
#   1.0: 'Agree very strongly with 1',
#   2.0: 'Agree with 1',
#   3.0: 'Agree with 2',
#   4.0: 'Agree very strongly with 2',
#   5.0: 'Agree with neither',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q16': {-1.0: 'Missing',
#   1.0: 'Agree very strongly with 1',
#   2.0: 'Agree with 1',
#   3.0: 'Agree with 2',
#   4.0: 'Agree very strongly with 2',
#   5.0: 'Agree with neither',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q17': {-1.0: 'Missing',
#   1.0: 'Agree very strongly with 1',
#   2.0: 'Agree with 1',
#   3.0: 'Agree with 2',
#   4.0: 'Agree very strongly with 2',
#   5.0: 'Agree with neither',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q18A': {-1.0: 'Missing',
#   0.0: 'Not at all likely',
#   1.0: 'Not very likely',
#   2.0: 'Somewhat likely',
#   3.0: 'Very likely',
#   8.0: 'Refused',
#   9.0: 'Don’t know/Haven’t heard'},
#  'Q18B': {-1.0: 'Missing',
#   0.0: 'Not at all likely',
#   1.0: 'Not very likely',
#   2.0: 'Somewhat likely',
#   3.0: 'Very likely',
#   8.0: 'Refused',
#   9.0: 'Don’t know/Haven’t heard'},
#  'Q18C': {-1.0: 'Missing',
#   0.0: 'Not at all likely',
#   1.0: 'Not very likely',
#   2.0: 'Somewhat likely',
#   3.0: 'Very likely',
#   8.0: 'Refused',
#   9.0: 'Don’t know/Haven’t heard'},
#  'Q18D': {-1.0: 'Missing',
#   0.0: 'Not at all likely',
#   1.0: 'Not very likely',
#   2.0: 'Somewhat likely',
#   3.0: 'Very likely',
#   8.0: 'Refused',
#   9.0: 'Don’t know/Haven’t heard'},
#  'Q19A': {-1.0: 'Missing',
#   1.0: 'Much less freedom',
#   2.0: 'Somewhat less freedom',
#   3.0: 'Same',
#   4.0: 'Somewhat more freedom',
#   5.0: 'Much more freedom',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q19B': {-1.0: 'Missing',
#   1.0: 'Much less freedom',
#   2.0: 'Somewhat less freedom',
#   3.0: 'Same',
#   4.0: 'Somewhat more freedom',
#   5.0: 'Much more freedom',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q19C': {-1.0: 'Missing',
#   1.0: 'Much less freedom',
#   2.0: 'Somewhat less freedom',
#   3.0: 'Same',
#   4.0: 'Somewhat more freedom',
#   5.0: 'Much more freedom',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q19D': {-1.0: 'Missing',
#   1.0: 'Much less freedom',
#   2.0: 'Somewhat less freedom',
#   3.0: 'Same',
#   4.0: 'Somewhat more freedom',
#   5.0: 'Much more freedom',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q19E': {-1.0: 'Missing',
#   1.0: 'Much less freedom',
#   2.0: 'Somewhat less freedom',
#   3.0: 'Same',
#   4.0: 'Somewhat more freedom',
#   5.0: 'Much more freedom',
#   8.0: 'Refused',
#   9.0: 'Don’t know'},
#  'Q20A': {-1.0: 'Missing',
#   0.0: 'Not a Member',
#   1.0: 'Inactive Member',
#   2.0: 'Active Member',
#   3.0: 'Official Leader',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q20B': {-1.0: 'Missing',
#   0.0: 'Not a Member',
#   1.0: 'Inactive Member',
#   2.0: 'Active Member',
#   3.0: 'Official Leader',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q21A': {-1.0: 'Missing',
#   0.0: 'No, would never do this',
#   1.0: 'No, but would do if had the chance',
#   2.0: 'Yes, once or twice',
#   3.0: 'Yes, several times',
#   4.0: 'Yes, often',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q21B': {-1.0: 'Missing',
#   0.0: 'No, would never do this',
#   1.0: 'No, but would do if had the chance',
#   2.0: 'Yes, once or twice',
#   3.0: 'Yes, several times',
#   4.0: 'Yes, often',
#   8.0: 'Refused',
#   9.0: "Don't know"},
#  'Q22': {-1.0: 'Missing',
#   0.0: 'You were not registered to vote',
#   1.0: 'You voted in the elections',
#   2.0: 'You decided not to vote',
#   3.0: 'You could not find the polling station',
#   4.0: 'You were prevented from voting',
#   5.0: 'You did not have time to vote',
#   6.0: 'You did not vote because your name not in the register',
# ...
#   1257.0: 'Lamnso',
#   1258.0: 'Tikari',
#   1259.0: 'Toupouri',
#   1263.0: 'Agny',
#   1264.0: 'Attié',
#   1265.0: 'Avikam',
#   1266.0: 'Bambara',
#   1267.0: 'Baoulé',
#   1268.0: 'Bété',
#   1276.0: 'Malinké / Dioula',
#   1500.0: 'Arabic',
#   1501.0: 'Moroccan Arabic',
#   1502.0: 'Arabic Hassani',
#   1503.0: 'Amazigh',
#   1540.0: 'Sudanese Arabic',
#   1541.0: 'Nubian language',
#   1542.0: 'Dinka language',
#   1543.0: 'Beja language',
#   1581.0: 'Arabic',
#   1660.0: 'Crioulo',
#   1661.0: 'Forro',
#   1662.0: 'Angular',
#   1663.0: 'Lunguie',
#   1700.0: 'Fang',
#   1701.0: 'Punu/Mériè',
#   1704.0: 'Nzébi/Métié',
#   1706.0: 'Tsogho',
#   1740.0: 'Fula',
#   1741.0: 'Wolof',
#   1742.0: 'Jola',
#   1743.0: 'Mandinka',
#   2220.0: 'Yamba',
#   2221.0: 'Yabassi',
#   2222.0: 'Bene',
#   9995.0: 'Other',
#   9996.0: 'No further reply'},
#  'Q119_2': {1.0: 'English',
#   2.0: 'French',
#   4.0: 'Swahili',
#   100.0: 'Adjagbé',
#   101.0: 'Baatonum',
#   102.0: 'Dendi',
#   103.0: 'Ditammari',
#   104.0: 'Fongbé',
#   106.0: 'Yoruba',
#   107.0: 'Lokpa',
#   140.0: 'Setswana',
#   180.0: 'Mooré',
#   182.0: 'Fulfudé',
#   221.0: 'Português',
#   260.0: 'Akan',
#   261.0: 'Ewe/Anlo',
#   262.0: 'Ga/Adangbe',
#   263.0: 'Dagbani',
#   301.0: 'Luo',
#   305.0: 'Kisii',
#   340.0: 'Sesotho',
#   381.0: 'Grebo',
#   383.0: 'Krahn',
#   384.0: 'Gio',
#   385.0: 'Mano',
#   386.0: 'Kpelle',
#   387.0: 'Lorma',
#   393.0: 'Vai',
#   420.0: '"Official" Malagasy',
#   421.0: 'Malagasy with regional dialect',
#   460.0: 'Chitumbuka',
#   461.0: 'Chinkhonde',
#   463.0: 'Chichewa',
#   501.0: 'Bambara',
#   540.0: 'Makua',
#   541.0: 'Sena',
#   542.0: 'Ndau',
#   543.0: 'Changana',
#   544.0: 'Nyanja',
#   545.0: 'Chope',
#   546.0: 'Bitonga',
#   548.0: 'Chuabo',
#   552.0: 'Xitswa',
#   580.0: 'Afrikaans',
#   583.0: 'Oshiwambo (Oshindonga/Oshikwanyama)',
#   584.0: 'Otjiherero',
#   588.0: 'Silozi',
#   620.0: 'Hausa',
#   621.0: 'Igbo',
#   622.0: 'Yoruba',
#   623.0: 'Pidgin English',
#   629.0: 'Kanuri',
#   660.0: 'Wolof',
#   700.0: 'Afrikaans',
#   701.0: 'Ndebele',
#   702.0: 'Xhosa',
#   703.0: 'Pedi/North Sotho',
#   704.0: 'Sotho/South Sotho',
#   705.0: 'Tswana',
#   706.0: 'Shangaan',
#   707.0: 'Swazi',
#   708.0: 'Venda',
#   709.0: 'Zulu',
#   741.0: 'Kichaga',
#   742.0: 'Kihaya',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   820.0: 'Bemba',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   860.0: 'Ndebele',
#   861.0: 'Shona',
#   931.0: 'Fulla',
#   932.0: 'Kissi',
#   936.0: 'Limba',
#   939.0: 'Mende',
#   941.0: 'Susu',
#   1101.0: 'Zrama/Songhay',
#   1103.0: 'Tamasheq',
#   1140.0: 'Ewé',
#   1141.0: 'Mina (Guen)',
#   1142.0: 'Kabyè',
#   1143.0: 'Tem (Kotokoli)',
#   1144.0: 'Ben (Moba)',
#   1220.0: 'Foufouldé',
#   1221.0: 'Pidgin',
#   1222.0: 'Ewondo',
#   1234.0: 'Bassa',
#   1263.0: 'Agny',
#   1267.0: 'Baoulé',
#   1268.0: 'Bété',
#   1273.0: 'Koulango',
#   1276.0: 'Malinké / Dioula',
#   1300.0: 'Mano',
#   1301.0: 'Maninka',
#   1305.0: 'Poular',
#   1306.0: 'Sossou',
#   1500.0: 'Arabic',
#   1501.0: 'Moroccan Arabic',
#   1620.0: 'siSwati',
#   1660.0: 'Crioulo',
#   1661.0: 'Forro',
#   1700.0: 'Fang',
#   1701.0: 'Punu/Mériè',
#   1704.0: 'Nzébi/Métié',
#   1706.0: 'Tsogho',
#   1740.0: 'Fula',
#   1741.0: 'Wolof',
#   1742.0: 'Jola',
#   1743.0: 'Mandinka',
#   9995.0: 'Other',
#   9996.0: 'No further reply'},
#  'Q119_3': {1.0: 'English',
#   4.0: 'Swahili',
#   101.0: 'Baatonum',
#   102.0: 'Dendi',
#   103.0: 'Ditammari',
#   104.0: 'Fongbé',
#   105.0: 'Fulfuldé',
#   106.0: 'Yoruba',
#   112.0: 'Idaasha',
#   113.0: 'Idatcha',
#   142.0: 'Sekgalagadi',
#   144.0: 'Ikalanga/Sekalaka',
#   147.0: 'Sebirwa',
#   150.0: 'Afrikaans/Seburu',
#   181.0: 'Dioula',
#   182.0: 'Fulfudé',
#   183.0: 'Gulmacema',
#   261.0: 'Ewe/Anlo',
#   262.0: 'Ga/Adangbe',
#   263.0: 'Dagbani',
#   300.0: 'Kukuyu',
#   301.0: 'Luo',
#   302.0: 'Luhya',
#   303.0: 'Kamba',
#   304.0: 'Kalenjin',
#   305.0: 'Kisii',
#   342.0: 'Sethepu',
#   392.0: 'Bassa',
#   420.0: '"Official" Malagasy',
#   421.0: 'Malagasy with regional dialect',
#   461.0: 'Chinkhonde',
#   462.0: 'Chilambya',
#   463.0: 'Chichewa',
#   464.0: 'Chiyao',
#   502.0: 'Bella',
#   503.0: 'Bobo',
#   504.0: 'Bozo',
#   509.0: 'Malinké',
#   513.0: 'Peulh / Fulfude',
#   515.0: 'Senufo',
#   516.0: 'Soninké / Sarakollé',
#   517.0: 'Sonrhaï',
#   540.0: 'Makua',
#   541.0: 'Sena',
#   542.0: 'Ndau',
#   545.0: 'Chope',
#   546.0: 'Bitonga',
#   547.0: 'Makonde',
#   548.0: 'Chuabo',
#   549.0: 'Ajaua',
#   550.0: 'Lomue',
#   551.0: 'Shona',
#   552.0: 'Xitswa',
#   553.0: 'Xironga',
#   554.0: 'Chichewa',
#   583.0: 'Oshiwambo (Oshindonga/Oshikwanyama)',
#   584.0: 'Otjiherero',
#   585.0: 'Rukwangali',
#   587.0: 'Thimbukushu',
#   588.0: 'Silozi',
#   590.0: 'Masubia',
#   621.0: 'Igbo',
#   622.0: 'Yoruba',
#   623.0: 'Pidgin English',
#   624.0: 'Efik',
#   627.0: 'Isoko',
#   628.0: 'Ibibio',
#   629.0: 'Kanuri',
#   633.0: 'Edo',
#   634.0: 'Igala',
#   638.0: 'Ikwere',
#   661.0: 'Pulaar/Toucouleur',
#   662.0: 'Serer',
#   663.0: 'Mandinka/Bambara',
#   701.0: 'Ndebele',
#   702.0: 'Xhosa',
#   703.0: 'Pedi/North Sotho',
#   704.0: 'Sotho/South Sotho',
#   705.0: 'Tswana',
#   706.0: 'Shangaan',
#   707.0: 'Swazi',
#   709.0: 'Zulu',
#   740.0: 'Kinyakyusa',
#   741.0: 'Kichaga',
#   742.0: 'Kihaya',
#   745.0: 'Kipare',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   861.0: 'Shona',
#   862.0: 'Zezuru',
#   864.0: 'Karanga',
#   865.0: 'Manyika',
#   866.0: 'Ndau',
#   900.0: 'Creole',
#   939.0: 'Mende',
#   942.0: 'Temne',
#   1102.0: 'Fulfuldé',
#   1103.0: 'Tamasheq',
#   1106.0: 'Arabe',
#   1141.0: 'Mina (Guen)',
#   1142.0: 'Kabyè',
#   1143.0: 'Tem (Kotokoli)',
#   1144.0: 'Ben (Moba)',
#   1145.0: 'Nawdem (Losso)',
#   1149.0: 'N’Tcha (Bassar)',
#   1150.0: 'Adja',
#   1152.0: 'Gourma',
#   1157.0: 'Ouatchi',
#   1220.0: 'Foufouldé',
#   1222.0: 'Ewondo',
#   1233.0: 'Banso',
#   1234.0: 'Bassa',
#   1237.0: 'Bula',
#   1254.0: 'Moudan',
#   1268.0: 'Bété',
#   1270.0: 'Godié',
#   1272.0: 'Guéré',
#   1301.0: 'Maninka',
#   1302.0: 'Loma',
#   1303.0: 'Kpèlè',
#   1304.0: 'Kissié',
#   1305.0: 'Poular',
#   1306.0: 'Sossou',
#   1501.0: 'Moroccan Arabic',
#   1503.0: 'Amazigh',
#   1621.0: 'Zulu',
#   1661.0: 'Forro',
#   1741.0: 'Wolof',
#   1743.0: 'Mandinka',
#   2222.0: 'Bene',
#   9995.0: 'Other',
#   9996.0: 'No further reply'},
#  'Q119_4': {1.0: 'English',
#   4.0: 'Swahili',
#   102.0: 'Dendi',
#   104.0: 'Fongbé',
#   106.0: 'Yoruba',
#   107.0: 'Lokpa',
#   182.0: 'Fulfudé',
#   184.0: 'Gourounsi',
#   185.0: 'Bissa',
#   188.0: 'Dagari',
#   192.0: 'Bwamu',
#   262.0: 'Ga/Adangbe',
#   263.0: 'Dagbani',
#   264.0: 'Dagaare',
#   421.0: 'Malagasy with regional dialect',
#   462.0: 'Chilambya',
#   463.0: 'Chichewa',
#   467.0: 'Chimang’anja',
#   468.0: 'Chisena',
#   471.0: 'Chitonga',
#   513.0: 'Peulh / Fulfude',
#   516.0: 'Soninké / Sarakollé',
#   517.0: 'Sonrhaï',
#   542.0: 'Ndau',
#   543.0: 'Changana',
#   546.0: 'Bitonga',
#   547.0: 'Makonde',
#   550.0: 'Lomue',
#   551.0: 'Shona',
#   552.0: 'Xitswa',
#   553.0: 'Xironga',
#   554.0: 'Chichewa',
#   555.0: 'Cinyungwe',
#   556.0: 'Ciyao',
#   558.0: 'Kimwani',
#   584.0: 'Otjiherero',
#   586.0: 'Rugririku/Rumanyo',
#   588.0: 'Silozi',
#   589.0: 'Setswana',
#   623.0: 'Pidgin English',
#   624.0: 'Efik',
#   626.0: 'Fulani',
#   628.0: 'Ibibio',
#   633.0: 'Edo',
#   665.0: 'Diola',
#   703.0: 'Pedi/North Sotho',
#   704.0: 'Sotho/South Sotho',
#   705.0: 'Tswana',
#   707.0: 'Swazi',
#   708.0: 'Venda',
#   709.0: 'Zulu',
#   745.0: 'Kipare',
#   750.0: 'Kimasai',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   837.0: 'Ila',
#   865.0: 'Manyika',
#   866.0: 'Ndau',
#   869.0: 'Tonga',
#   872.0: 'Hwesa',
#   873.0: 'Sotho',
#   942.0: 'Temne',
#   1103.0: 'Tamasheq',
#   1143.0: 'Tem (Kotokoli)',
#   1150.0: 'Adja',
#   1152.0: 'Gourma',
#   1157.0: 'Ouatchi',
#   1257.0: 'Lamnso',
#   1276.0: 'Lobi',
#   1303.0: 'Kpèlè',
#   1304.0: 'Kissié',
#   1305.0: 'Poular',
#   1306.0: 'Sossou',
#   1503.0: 'Amazigh',
#   1662.0: 'Angular',
#   1743.0: 'Mandinka',
#   9995.0: 'Other',
#   9996.0: 'No further reply'},
#  'Q119_5': {1.0: 'English',
#   4.0: 'Swahili',
#   104.0: 'Fongbé',
#   105.0: 'Fulfuldé',
#   196.0: 'Kassena',
#   463.0: 'Chichewa',
#   464.0: 'Chiyao',
#   468.0: 'Chisena',
#   471.0: 'Chitonga',
#   518.0: 'Tamasheq',
#   544.0: 'Nyanja',
#   552.0: 'Xitswa',
#   555.0: 'Cinyungwe',
#   556.0: 'Ciyao',
#   558.0: 'Kimwani',
#   587.0: 'Thimbukushu',
#   590.0: 'Masubia',
#   624.0: 'Efik',
#   628.0: 'Ibibio',
#   630.0: 'Tiv',
#   633.0: 'Edo',
#   634.0: 'Igala',
#   704.0: 'Sotho/South Sotho',
#   705.0: 'Tswana',
#   709.0: 'Zulu',
#   750.0: 'Kimasai',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   827.0: 'Kaonde',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   842.0: 'Lala',
#   872.0: 'Hwesa',
#   1145.0: 'Nawdem (Losso)',
#   1157.0: 'Ouatchi',
#   1306.0: 'Sossou',
#   9995.0: 'Other',
#   9996.0: 'No further reply'},
#  'Q119_6': {1.0: 'English',
#   4.0: 'Swahili',
#   106.0: 'Yoruba',
#   469.0: 'Chisukwa',
#   471.0: 'Chitonga',
#   549.0: 'Ajaua',
#   551.0: 'Shona',
#   628.0: 'Ibibio',
#   640.0: 'Esan',
#   705.0: 'Tswana',
#   706.0: 'Shangaan',
#   709.0: 'Zulu',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   9995.0: 'Other',
#   9996.0: 'No further reply'},
#  'Q119_7': {1.0: 'English',
#   4.0: 'Swahili',
#   708.0: 'Venda',
#   709.0: 'Zulu',
#   780.0: 'Luganda',
#   781.0: 'Runyankole',
#   782.0: 'Runyoro',
#   783.0: 'Lusoga',
#   784.0: 'Lumasaaba',
#   785.0: 'Lukhonjo',
#   786.0: 'Lunyole',
#   787.0: 'Ateso',
#   788.0: 'Acholi',
#   789.0: 'Alur',
#   790.0: 'Lugbara',
#   791.0: 'Madi',
#   792.0: 'Japadhola',
#   793.0: 'Lusamia',
#   794.0: 'Lugwere',
#   795.0: 'Rukiga',
#   796.0: 'Rutooro',
#   797.0: 'Langi',
#   798.0: 'Kupsabinyi',
#   799.0: 'Ngakarimajong',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   835.0: 'Ngoni',
#   837.0: 'Ila',
#   842.0: 'Lala',
#   9995.0: 'Other',
#   9996.0: 'No further reply'},
#  'Q119_8': {-1.0: 'Missing',
#   1.0: 'English',
#   709.0: 'Zulu',
#   820.0: 'Bemba',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   831.0: 'Bisa',
#   832.0: 'Nkoya',
#   833.0: 'Mambwe',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   836.0: 'Soli',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   839.0: 'Chokwe',
#   840.0: 'Mbunda',
#   841.0: 'Kunda',
#   842.0: 'Lala',
#   843.0: 'Lamba',
#   844.0: 'Lungu',
#   845.0: 'Nyika',
#   846.0: 'Senga',
#   847.0: 'Tokaleya',
#   848.0: 'Bwile',
#   849.0: 'Ngumbo',
#   850.0: 'Chishinga',
#   851.0: 'Tabwa',
#   852.0: 'Goba',
#   9995.0: 'Other',
#   9996.0: 'No Further Response',
#   9998.0: 'Refused to Answer',
#   9999.0: "Don't know"},
#  'Q119_9': {-1.0: 'Missing',
#   1.0: 'English',
#   820.0: 'Bemba',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   831.0: 'Bisa',
#   832.0: 'Nkoya',
#   833.0: 'Mambwe',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   836.0: 'Soli',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   839.0: 'Chokwe',
#   840.0: 'Mbunda',
#   841.0: 'Kunda',
#   842.0: 'Lala',
#   843.0: 'Lamba',
#   844.0: 'Lungu',
#   845.0: 'Nyika',
#   846.0: 'Senga',
#   847.0: 'Tokaleya',
#   848.0: 'Bwile',
#   849.0: 'Ngumbo',
#   850.0: 'Chishinga',
#   851.0: 'Tabwa',
#   852.0: 'Goba',
#   9995.0: 'Other',
#   9996.0: 'No Further Response',
#   9998.0: 'Refused to Answer',
#   9999.0: "Don't know"},
#  'Q119_10': {-1.0: 'Missing',
#   1.0: 'English',
#   820.0: 'Bemba',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   831.0: 'Bisa',
#   832.0: 'Nkoya',
#   833.0: 'Mambwe',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   836.0: 'Soli',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   839.0: 'Chokwe',
#   840.0: 'Mbunda',
#   841.0: 'Kunda',
#   842.0: 'Lala',
#   843.0: 'Lamba',
#   844.0: 'Lungu',
#   845.0: 'Nyika',
#   846.0: 'Senga',
#   847.0: 'Tokaleya',
#   848.0: 'Bwile',
#   849.0: 'Ngumbo',
#   850.0: 'Chishinga',
#   851.0: 'Tabwa',
#   852.0: 'Goba',
#   9995.0: 'Other',
#   9996.0: 'No Further Response',
#   9998.0: 'Refused to Answer',
#   9999.0: "Don't know"},
#  'Q119_11': {-1.0: 'Missing',
#   1.0: 'English',
#   820.0: 'Bemba',
#   821.0: 'Nyanja',
#   822.0: 'Tonga',
#   823.0: 'Lozi',
#   824.0: 'Chewa',
#   825.0: 'Nsenga',
#   826.0: 'Tumbuka',
#   827.0: 'Kaonde',
#   828.0: 'Luvale',
#   829.0: 'Namwanga',
#   830.0: 'Lunda',
#   831.0: 'Bisa',
#   832.0: 'Nkoya',
#   833.0: 'Mambwe',
#   834.0: 'Lenje',
#   835.0: 'Ngoni',
#   836.0: 'Soli',
#   837.0: 'Ila',
#   838.0: 'Ushi',
#   839.0: 'Chokwe',
#   840.0: 'Mbunda',
#   841.0: 'Kunda',
#   842.0: 'Lala',
#   843.0: 'Lamba',
#   844.0: 'Lungu',
#   845.0: 'Nyika',
#   846.0: 'Senga',
#   847.0: 'Tokaleya',
#   848.0: 'Bwile',
#   849.0: 'Ngumbo',
#   850.0: 'Chishinga',
#   851.0: 'Tabwa',
#   852.0: 'Goba',
#   9995.0: 'Other',
#   9996.0: 'No Further Response',
#   9998.0: 'Refused to Answer',
#   9999.0: "Don't know"},
#  'URBRUR_COND': {1.0: 'Urban', 2.0: 'Rural'},
#  'AGE_COND': {1.0: '18-25',
#   2.0: '26-35',
#   3.0: '36-45',
#   4.0: '46-55',
#   5.0: '56-65',
#   6.0: 'Over 65',
#   9.0: "Don't know"},
#  'EDUC_COND': {0.0: 'No formal education',
#   1.0: 'Primary',
#   2.0: 'Secondary',
#   3.0: 'Post-secondary',
#   9.0: "Don't know"},
#  'RELIG_COND': {1.0: 'Christian',
#   2.0: 'Muslim',
#   3.0: 'Other',
#   9.0: "Don't know"},
#  'LivedPoverty_CAT': {0.0: 'No Lived Poverty',
#   1.0: 'Low Lived Poverty',
#   2.0: 'Moderate Lived Poverty',
#   3.0: 'High Lived Poverty'},
#  'DemandDemo': {0.0: 'No demand for democracy',
#   1.0: 'Agrees w/ 1 of 4 components',
#   2.0: 'Agrees w/ 2 of 4 components',
#   3.0: 'Agrees w/ 3 of 4 components',
#   4.0: 'Full demand for democracy'},
#  'SupplyDemo': {0.0: 'Perceives no supply',
#   1.0: 'Perceives supply of one, not both',
#   2.0: 'Perceives full supply of democracy (Extent +Satisfaction)'},
#  'R1.only': {0.0: 'Not Selected', 1.0: 'Selected'},
#  'R2.only': {0.0: 'Not Selected', 1.0: 'Selected'},
#  'R3.only': {0.0: 'Not Selected', 1.0: 'Selected'},
#  'R4.only': {0.0: 'Not Selected', 1.0: 'Selected'},
#  'R5.only': {0.0: 'Not Selected', 1.0: 'Selected'},
#  'R6.only': {0.0: 'Not Selected', 1.0: 'Selected'}}

# %%
mask = df['country'] == 'Nigeria'
df_nigeria = df[mask]

df_nigeria.head()
# Out:
#          country community    state                ctry_direction  \
# id
# NIG0001  Nigeria     Rural   Bauchi  Going in the wrong direction
# NIG0002  Nigeria     Urban  Anambra  Going in the wrong direction
# NIG0003  Nigeria     Urban  Anambra  Going in the wrong direction
# NIG0004  Nigeria     Rural   Jigawa  Going in the wrong direction
# NIG0005  Nigeria     Rural    Niger  Going in the wrong direction
#
#         ctry_present_econ rel_econ_past12m fear_pol_intimidation  \
# id
# NIG0001         Very good           Better          A little bit
# NIG0002        Fairly Bad            Worse          A little bit
# NIG0003        Fairly Bad            Worse          A little bit
# NIG0004         Very good            Worse            Not at all
# NIG0005        Fairly Bad           Better                 A lot
#
#           trust_police pay_bribe_police
# id
# NIG0001  Just a little    Once or twice
# NIG0002     Not at all            Never
# NIG0003          A lot    Once or twice
# NIG0004  Just a little       No contact
# NIG0005  Just a little       No contact

# %%
df_piv = (df_nigeria['state']
             .groupby(df_nigeria['ctry_direction'])
             .value_counts()
             .rename('frequency')
             .to_frame()
             .reset_index()
            )

df_piv
# Out:
#                   ctry_direction      state  frequency
# 0                     Don't know     Jigawa          3
# 1                     Don't know       Kogi          2
# 2                     Don't know     Bauchi          1
# 3                     Don't know      Enugu          1
# 4                     Don't know       Kano          1
# ..                           ...        ...        ...
# 73  Going in the wrong direction    Zamfara         13
# 74  Going in the wrong direction     Taraba         10
# 75  Going in the wrong direction  Fct Abuja          8
# 76  Going in the wrong direction      Kebbi          6
# 77  Going in the wrong direction   Nasarawa          6
#
# [78 rows x 3 columns]

# %%
df_piv[df_piv['ctry_direction'] == "Going in the wrong direction"]
# Out:
#                   ctry_direction        state  frequency
# 41  Going in the wrong direction        Lagos   0.088757
# 42  Going in the wrong direction       Rivers   0.059172
# 43  Going in the wrong direction          Oyo   0.055227
# 44  Going in the wrong direction      Anambra   0.051282
# 45  Going in the wrong direction        Enugu   0.046351
# 46  Going in the wrong direction          Imo   0.044379
# 47  Going in the wrong direction        Delta   0.041420
# 48  Going in the wrong direction         Abia   0.038462
# 49  Going in the wrong direction         Ogun   0.035503
# 50  Going in the wrong direction         Osun   0.035503
# 51  Going in the wrong direction    Akwa Ibom   0.032544
# 52  Going in the wrong direction         Ondo   0.031558
# 53  Going in the wrong direction        Borno   0.029586
# 54  Going in the wrong direction          Edo   0.028600
# 55  Going in the wrong direction         Kano   0.028600
# 56  Going in the wrong direction      Bayelsa   0.023669
# 57  Going in the wrong direction         Kogi   0.023669
# 58  Going in the wrong direction      Adamawa   0.022682
# 59  Going in the wrong direction       Ebonyi   0.022682
# 60  Going in the wrong direction       Bauchi   0.021696
# 61  Going in the wrong direction      Plateau   0.021696
# 62  Going in the wrong direction  Cross River   0.020710
# 63  Going in the wrong direction        Benue   0.018738
# 64  Going in the wrong direction        Ekiti   0.016765
# 65  Going in the wrong direction        Kwara   0.016765
# 66  Going in the wrong direction        Gombe   0.015779
# 67  Going in the wrong direction        Niger   0.015779
# 68  Going in the wrong direction       Sokoto   0.015779
# 69  Going in the wrong direction       Kaduna   0.013807
# 70  Going in the wrong direction      Katsina   0.013807
# 71  Going in the wrong direction         Yobe   0.013807
# 72  Going in the wrong direction       Jigawa   0.012821
# 73  Going in the wrong direction      Zamfara   0.012821
# 74  Going in the wrong direction       Taraba   0.009862
# 75  Going in the wrong direction    Fct Abuja   0.007890
# 76  Going in the wrong direction        Kebbi   0.005917
# 77  Going in the wrong direction     Nasarawa   0.005917

# %%
df_nigeria['ctry_direction'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Perception of Nigeria's overall direction by citizens");

# %%
df_nigeria['ctry_present_econ'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Perception of Nigeria's economic situation by citizens");

# %%
df_nigeria['rel_econ_past12m'].value_counts(normalize=True).sort_values()
# Out:
# Refused        0.000625
# Don’t know     0.001250
# Much better    0.054375
# Much worse     0.156875
# Same           0.164375
# Better         0.294375
# Worse          0.328125
# Name: rel_econ_past12m, dtype: float64

# %%
df_nigeria['rel_econ_past12m'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Perception of the change in Nigeria's economic situation by citizens");

# %%
df_nigeria['fear_pol_intimidation'].value_counts()
# Out:
# Not at all      578
# A little bit    480
# A lot           282
# Somewhat        256
# Refused           2
# Don’t know        2
# Name: fear_pol_intimidation, dtype: int64

# %%
df_nigeria['trust_police'].value_counts()
# Out:
# Not at all                         765
# Just a little                      399
# Somewhat                           272
# A lot                              151
# Don’t know/Haven’t heard enough     11
# Refused                              2
# Name: trust_police, dtype: int64

# %%
df_nigeria['pay_bribe_police'].value_counts()
# Out:
# No contact       867
# Never            403
# Once or twice    138
# A few times      101
# Often             91
# Name: pay_bribe_police, dtype: int64

# %%
df.country.value_counts()
# Out:
# Ghana                    2400
# Tanzania                 2400
# Mozambique               2392
# South Africa             1840
# Nigeria                  1600
# Kenya                    1599
# Cameroon                 1202
# Namibia                  1200
# Madagascar               1200
# Zimbabwe                 1200
# Côte d'Ivoire            1200
# Cabo Verde               1200
# Malawi                   1200
# Sierra Leone             1200
# Sudan                    1200
# Lesotho                  1200
# Benin                    1200
# Uganda                   1200
# Gambia                   1200
# Togo                     1200
# São Tomé and Príncipe    1200
# Burkina Faso             1200
# Senegal                  1200
# Niger                    1200
# Mali                     1200
# Liberia                  1200
# eSwatini                 1200
# Zambia                   1200
# Mauritius                1200
# Morocco                  1200
# Gabon                    1199
# Tunisia                  1199
# Botswana                 1198
# Guinea                   1194
# Name: country, dtype: int64

# %%
df_nigeria['ctry_direction'].value_counts(normalize=True)
# Out:
# Going in the wrong direction    0.633750
# Going in the right direction    0.360625
# Don't know                      0.005625
# Name: ctry_direction, dtype: float64

# %%
pivotal = df_nigeria[['state', 'ctry_direction']].value_counts().to_frame()

# %%
pivotal.reset_index(inplace=True)

# %%
pivotal_pivot = pivotal.pivot(index='state', columns='ctry_direction')

# %%
pivotal_pivot
# Out:
#                         0                               \
# ctry_direction Don't know Going in the right direction
# state
# Abia                  NaN                          1.0
# Adamawa               NaN                          9.0
# Akwa Ibom             NaN                         15.0
# Anambra               NaN                          4.0
# Bauchi                1.0                         25.0
# Bayelsa               NaN                          NaN
# Benue                 NaN                         29.0
# Borno                 NaN                         18.0
# Cross River           NaN                         11.0
# Delta                 NaN                          6.0
# Ebonyi                NaN                          1.0
# Edo                   NaN                         11.0
# Ekiti                 NaN                          7.0
# Enugu                 1.0                          NaN
# Fct Abuja             NaN                          8.0
# Gombe                 NaN                          8.0
# Imo                   NaN                          3.0
# Jigawa                3.0                         32.0
# Kaduna                NaN                         50.0
# Kano                  1.0                         66.0
# Katsina               NaN                         42.0
# Kebbi                 NaN                         26.0
# Kogi                  2.0                          6.0
# Kwara                 NaN                          7.0
# Lagos                 NaN                         38.0
# Nasarawa              NaN                         10.0
# Niger                 NaN                         24.0
# Ogun                  NaN                         12.0
# Ondo                  NaN                          8.0
# Osun                  NaN                          4.0
# Oyo                   NaN                         16.0
# Plateau               1.0                          9.0
# Rivers                NaN                          4.0
# Sokoto                NaN                         24.0
# Taraba                NaN                         14.0
# Yobe                  NaN                         10.0
# Zamfara               NaN                         19.0
#
#
# ctry_direction Going in the wrong direction
# state
# Abia                                   39.0
# Adamawa                                23.0
# Akwa Ibom                              33.0
# Anambra                                52.0
# Bauchi                                 22.0
# Bayelsa                                24.0
# Benue                                  19.0
# Borno                                  30.0
# Cross River                            21.0
# Delta                                  42.0
# Ebonyi                                 23.0
# Edo                                    29.0
# Ekiti                                  17.0
# Enugu                                  47.0
# Fct Abuja                               8.0
# Gombe                                  16.0
# Imo                                    45.0
# Jigawa                                 13.0
# Kaduna                                 14.0
# Kano                                   29.0
# Katsina                                14.0
# Kebbi                                   6.0
# Kogi                                   24.0
# Kwara                                  17.0
# Lagos                                  90.0
# Nasarawa                                6.0
# Niger                                  16.0
# Ogun                                   36.0
# Ondo                                   32.0
# Osun                                   36.0
# Oyo                                    56.0
# Plateau                                22.0
# Rivers                                 60.0
# Sokoto                                 16.0
# Taraba                                 10.0
# Yobe                                   14.0
# Zamfara                                13.0

# %%
dir_diff_by_state =(pivotal_pivot[0]['Going in the right direction'] - pivotal_pivot[0]['Going in the wrong direction']).to_frame()

# %%
dir_diff_by_state.rename(columns={0:'direction_difference'}, inplace=True)

# %%
dir_diff_by_state.reset_index(inplace=True)

# %%
plt.rcParams["figure.figsize"] = (14,10)
ax = dir_diff_by_state.dropna().sort_values(by='direction_difference').plot.barh(y='direction_difference',
                                                                                 x='state', color='green', 
                                                                                 legend=False)
plt.ylabel('State')
plt.title('Difference between Nigerians that think Nigeria is going in the right direction and those that think it is going in the wrong direction by state');

# %%
dir_diff_by_state.sort_values(by='direction_difference')
# Out:
#           state  direction_difference
# 32       Rivers                 -56.0
# 24        Lagos                 -52.0
# 3       Anambra                 -48.0
# 16          Imo                 -42.0
# 30          Oyo                 -40.0
# 0          Abia                 -38.0
# 9         Delta                 -36.0
# 29         Osun                 -32.0
# 28         Ondo                 -24.0
# 27         Ogun                 -24.0
# 10       Ebonyi                 -22.0
# 11          Edo                 -18.0
# 2     Akwa Ibom                 -18.0
# 22         Kogi                 -18.0
# 1       Adamawa                 -14.0
# 31      Plateau                 -13.0
# 7         Borno                 -12.0
# 12        Ekiti                 -10.0
# 8   Cross River                 -10.0
# 23        Kwara                 -10.0
# 15        Gombe                  -8.0
# 35         Yobe                  -4.0
# 14    Fct Abuja                   0.0
# 4        Bauchi                   3.0
# 34       Taraba                   4.0
# 25     Nasarawa                   4.0
# 36      Zamfara                   6.0
# 33       Sokoto                   8.0
# 26        Niger                   8.0
# 6         Benue                  10.0
# 17       Jigawa                  19.0
# 21        Kebbi                  20.0
# 20      Katsina                  28.0
# 18       Kaduna                  36.0
# 19         Kano                  37.0
# 5       Bayelsa                   NaN
# 13        Enugu                   NaN

# %%
df.country.value_counts().index
# Out:
# Index(['Ghana', 'Tanzania', 'Mozambique', 'South Africa', 'Nigeria', 'Kenya',
#        'Cameroon', 'Namibia', 'Madagascar', 'Zimbabwe', 'Côte d'Ivoire',
#        'Cabo Verde', 'Malawi', 'Sierra Leone', 'Sudan', 'Lesotho', 'Benin',
#        'Uganda', 'Gambia', 'Togo', 'São Tomé and Príncipe', 'Burkina Faso',
#        'Senegal', 'Niger', 'Mali', 'Liberia', 'eSwatini', 'Zambia',
#        'Mauritius', 'Morocco', 'Gabon', 'Tunisia', 'Botswana', 'Guinea'],
#       dtype='object')

# %%
pip install plotly
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Nigerian Police

# %%
mask = df_police['country'] == 'Nigeria'
df_nigpol = df_police[mask]

df_nigpol.head()
# Out:
#        country    state  neigborhood_safety       fear_of_crime stolen_from  \
# 29184  Nigeria   Bauchi  Just once or twice               Never          No
# 29185  Nigeria  Anambra  Just once or twice               Never          No
# 29186  Nigeria  Anambra               Never               Never          No
# 29187  Nigeria   Jigawa               Never               Never          No
# 29188  Nigeria    Niger  Just once or twice  Just once or twice  Yes, twice
#
#                        attacked   trust_police corrupt_police  \
# 29184                Yes, twice  Just a little    All of them
# 29185                 Yes, once     Not at all   Some of them
# 29186                        No          A lot   Most of them
# 29187                        No  Just a little           None
# 29188  Yes, three or more times  Just a little           None
#
#       ease_of_police_assist time_to_police_assist paybribe_police_assist  \
# 29184            No contact            No contact             No contact
# 29185            No contact            No contact             No contact
# 29186             Difficult     After a long time          Once or twice
# 29187            No contact            No contact             No contact
# 29188            No contact            No contact             No contact
#
#       paybribe_avoid_police
# 29184         Once or twice
# 29185                 Never
# 29186         Once or twice
# 29187            No contact
# 29188            No contact

# %%
df_nigpol['stolen_from'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Stolen from", color='green');

# %%
df_nigpol['attacked'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Attacked", color='green');

# %%
df_nigpol['trust_police'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Trust in Police", color='green');

# %%
df_nigpol['corrupt_police'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Perception of police corruption", color='green');

# %%
df_nigpol['ease_of_police_assist'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Ease of Police assist", color='green');

# %%
df_nigpol['paybribe_police_assist'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Paying bribe to receive assistance from police", color='green');

# %%
df_nigpol['paybribe_avoid_police'].value_counts(normalize=True).sort_values().plot(kind='barh',
                                                                            title= "Paying bribe to avoid police", color='green');
