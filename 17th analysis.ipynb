# %%
# Import libraries
import pandas as pd
import pyreadstat as pyr

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from wrangle2021 import Wrangler

# %%
# Instantiate wrangle class
wrangle = Wrangler()

# %%
data = wrangle.wrangle(columns=['REGION','Q36'], rename=['State', 'Extent of democracy'])

# %%
wrangle.get_frequency(columns=['Extent of democracy'], df_new=data)
# Out:
# A democracy, but with minor problems      0.368355
# A democracy, with major problems          0.283927
# A full democracy                          0.212008
# Not a democracy                           0.118199
# Do not understand question / democracy    0.009381
# Don't know                                0.008130
# Name: Extent of democracy, dtype: float64

# %%
df_new = wrangle.remove(columns=['Extent of democracy'], df_new=data)

# %%
fig, ax = plt.subplots(figsize=(15, 10))
(df_new['Extent of democracy'].value_counts(normalize=True).
 sort_values()*100).plot(kind='pie', autopct='%1.0f%%', wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, ax=ax, title='What is the extent Nigerian democracy?')
ax.set(ylabel=None)
plt.xlabel('Percentage [%]');

# %%
fig = plt.figure()

# Needed to add spacing between 1st and 2nd row
# Add a margin between the main title and sub-plots
fig.subplots_adjust(hspace=0.4, top=2)

# Add the main title
fig.suptitle("2019 General Election", y=2.2, fontsize=15)


# Add the subplots
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)




# Plot for axis 1-3
(df_new['Police assist people to cast ballot?'].value_counts(normalize=True).sort_values()*100).plot(kind='barh', ax=ax1, color='green')
(df_new['Voter intimidation?'].value_counts(normalize=True).sort_values()*100).plot(kind='barh', ax=ax2, color='green')
(df_new['Accurate results?'].value_counts(normalize=True).sort_values()*100).plot(kind='barh', ax=ax3, color='green')

# Add the text for each subplot
ax1.title.set_text('Did the police assist people to cast their ballot?')
ax2.title.set_text('Was there voter intimidation?')
ax3.title.set_text('Were results accurate?')


# label
plt.xlabel('Percentage [%]')

plt.show()
