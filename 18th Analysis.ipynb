# %%
# Import libraries
import pandas as pd
import pyreadstat as pyr

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from wrangle2021 import Wrangler

# %%
# Instatiate wrangle class
wrangle = Wrangler()

# %%
# Wrangle the data from the database
data = wrangle.wrangle(columns=['REGION','Q37'], rename=['State', 'Satisfaction with democracy'])

# %%
# Get the distribution of data on the database
wrangle.get_frequency(columns=['Satisfaction with democracy'], df_new=df_new)
# Out:
# Not at all satisfied    0.329726
# Not very satisfied      0.301719
# Fairly satisfied        0.293444
# Very satisfied          0.075111
# Name: Satisfaction with democracy, dtype: float64

# %%
# Remove unessesary values
df_new = wrangle.remove(columns=['Satisfaction with democracy'], df_new=data)

# %%
# Plot values as a piechart using pandas
fig, ax = plt.subplots(figsize=(15, 10))
(df_new['Satisfaction with democracy'].value_counts(normalize=True).
 sort_values()*100).plot(kind='pie', autopct='%1.0f%%', wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, ax=ax, title='Satisfaction with democracy in Nigeria')
ax.set(ylabel=None)
plt.xlabel('Percentage [%]');
